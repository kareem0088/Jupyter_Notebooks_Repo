# %%
# استيراد المكتبات اللازمة
import pandas as pd
import lightgbm as lgb
import numpy as np
from termcolor import colored


# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')


# هنا سنفترض أننا نريد إدخال المدخلات يدويًا
input_data = {
    
    'Open': float(input('أدخل Open: ')),
    'High': float(input('أدخل High: ')),
    'Low': float(input('أدخل Low: ')),
    'Close': float(input('أدخل Close: ')),
    'Volume': float(input('أدخل Volume: ')),
    'EMA_100': float(input('أدخل EMA_100: ')),
    'EMA_50': float(input('أدخل EMA_50: ')),
    'EMA_21': float(input('أدخل EMA_21: ')),
    'EMA_13': float(input('أدخل EMA_13: ')),
    'EMA_7': float(input('أدخل EMA_7: ')),
    'RSI_10': float(input('أدخل RSI_10: ')),
    'ATR_10': float(input('أدخل ATR_10: ')),
    'ATR_30': float(input('أدخل ATR_30: '))
}

# تحويل المدخلات إلى DataFrame
input_df = pd.DataFrame([input_data])

# معالجة المدخلات بنفس طريقة معالجة البيانات التدريبية
#processed_input = preprocess_input(input_df)

# التأكد من ترتيب الأعمدة كما في التدريب
features = ['Open', 'High', 'Low', 'Close', 'Volume',
            'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
            'RSI_10', 'ATR_10', 'ATR_30']

#processed_input = processed_input[features]

# ترتيب الأعمدة كما في التدريب
input_df = input_df[features]

# التنبؤ باستخدام النموذج
prediction = model.predict(input_df)

# عرض النتيجة
print(f'التنبؤ: {prediction[0]}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 15
#       9 model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')
#      12 # هنا سنفترض أننا نريد إدخال المدخلات يدويًا
#      13 input_data = {
#      14
# ---> 15     'Open': float(input('أدخل Open: ')),
#      16     'High': float(input('أدخل High: ')),
#      17     'Low': float(input('أدخل Low: ')),
#      18     'Close': float(input('أدخل Close: ')),
#      19     'Volume': float(input('أدخل Volume: ')),
#      20     'EMA_100': float(input('أدخل EMA_100: ')),
#      21     'EMA_50': float(input('أدخل EMA_50: ')),
#      22     'EMA_21': float(input('أدخل EMA_21: ')),
#      23     'EMA_13': float(input('أدخل EMA_13: ')),
#      24     'EMA_7': float(input('أدخل EMA_7: ')),
#      25     'RSI_10': float(input('أدخل RSI_10: ')),
# ...

# %%
pip install termcolor
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install MetaTrader5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/50.0 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/50.0 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/50.0 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/50.0 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/50.0 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/50.0 kB ? eta -:--:--
#    ---------------- ----------------------- 20.5/50.0 kB 41.0 kB/s eta 0:00:01
#    ---------------- ----------------------- 20.5/50.0 kB 41.0 kB/s eta 0:00:01
#    ---------------- ----------------------- 20.5/50.0 kB 41.0 kB/s eta 0:00:01
#    ---------------- ----------------------- 20.5/50.0 kB 41.0 kB/s eta 0:00:01
#    ---------------- ----------------------- 20.5/50.0 kB 41.0 kB/s eta 0:00:01
# ...

# %%
pip install TA-Lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/368.5 kB ? eta -:--:--
#      - -------------------------------------- 10.2/368.5 kB ? eta -:--:--
#      -- ---------------------------------- 20.5/368.5 kB 330.3 kB/s eta 0:00:02
#      ---- -------------------------------- 41.0/368.5 kB 279.3 kB/s eta 0:00:02
#      --------- --------------------------- 92.2/368.5 kB 525.1 kB/s eta 0:00:01
#      ----------- ------------------------ 112.6/368.5 kB 595.3 kB/s eta 0:00:01
#      ----------- ------------------------ 112.6/368.5 kB 595.3 kB/s eta 0:00:01
#      ----------------- ------------------ 174.1/368.5 kB 551.6 kB/s eta 0:00:01
#      ----------------------- ------------ 235.5/368.5 kB 654.9 kB/s eta 0:00:01
#      ------------------------------- ---- 317.4/368.5 kB 785.7 kB/s eta 0:00:01
#      -----------------------------------  358.4/368.5 kB 825.0 kB/s eta 0:00:01
# ...

# %%
pip install pyproject.toml-based
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pyproject.toml-based (from versions: none)
# ERROR: No matching distribution found for pyproject.toml-based

# %%
# استيراد المكتبات اللازمة
import pandas as pd
import lightgbm as lgb
import MetaTrader5 as mt5
import talib
import numpy as np

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# معلومات تسجيل الدخول
account_number = 51915724  # رقم الحساب
password = "yqWAA@pt37$V1W"  # كلمة المرور
server = "ICMarketsGlobalSC-Demo"  # اسم الخادم

# تهيئة الاتصال بـ MetaTrader 5
if not mt5.initialize(login=account_number, password=password, server=server):
    print("Failed to initialize MT5")
    mt5.shutdown()

# تحديد الرمز الزمني والفترة الزمنية
symbol = "EURUSD"  # على سبيل المثال
timeframe = mt5.TIMEFRAME_M1  # دقيقة واحدة
num_bars = 100  # عدد الشموع المطلوبة لحساب المؤشرات

# الحصول على البيانات من MT5
rates = mt5.copy_rates_from_pos(symbol, timeframe, 0, num_bars)

# التأكد من إغلاق الاتصال بـ MetaTrader 5
mt5.shutdown()

# تحويل البيانات إلى DataFrame
if rates is None or len(rates) == 0:
    print("No data received from MT5")
else:
    rates_df = pd.DataFrame(rates)

    # حساب المؤشرات الفنية باستخدام TA-Lib
    rates_df['EMA_100'] = talib.EMA(rates_df['close'], timeperiod=100)
    rates_df['EMA_50'] = talib.EMA(rates_df['close'], timeperiod=50)
    rates_df['EMA_21'] = talib.EMA(rates_df['close'], timeperiod=21)
    rates_df['EMA_13'] = talib.EMA(rates_df['close'], timeperiod=13)
    rates_df['EMA_7'] = talib.EMA(rates_df['close'], timeperiod=7)
    rates_df['RSI_10'] = talib.RSI(rates_df['close'], timeperiod=10)
    rates_df['ATR_10'] = talib.ATR(rates_df['high'], rates_df['low'], rates_df['close'], timeperiod=10)
    rates_df['ATR_30'] = talib.ATR(rates_df['high'], rates_df['low'], rates_df['close'], timeperiod=30)

    # اختيار آخر صف للمدخلات
    input_data = rates_df.iloc[-1][['open', 'high', 'low', 'close', 'tick_volume',
                                    'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                                    'RSI_10', 'ATR_10', 'ATR_30']]

    # تحويل المدخلات إلى DataFrame
    input_df = pd.DataFrame([input_data])

    # التأكد من ترتيب الأعمدة كما في التدريب
    features = ['open', 'high', 'low', 'close', 'tick_volume',
                'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                'RSI_10', 'ATR_10', 'ATR_30']

    # ترتيب الأعمدة كما في التدريب
    input_df = input_df[features]

    # التنبؤ باستخدام النموذج
    prediction = model.predict(input_df)

    # عرض النتيجة
    print(f'التنبؤ: {prediction[0]}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import lightgbm as lgb
#       4 import MetaTrader5 as mt5
# ----> 5 import talib
#       6 import numpy as np
#       8 # تحميل النموذج المدرب
#
# ModuleNotFoundError: No module named 'talib'

# %%
# استيراد المكتبات اللازمة
import pandas as pd
import lightgbm as lgb
import MetaTrader5 as mt5
import pandas_ta as ta
import numpy as np

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# معلومات تسجيل الدخول
account_number = 51915724  # رقم الحساب
password = "yqWAA@pt37$V1W"  # كلمة المرور
server = "ICMarketsSC-Demo"  # اسم الخادم

# تهيئة الاتصال بـ MetaTrader 5
if not mt5.initialize(login=account_number, password=password, server=server):
    print("Failed to initialize MT5")
    mt5.shutdown()

# تحديد الرمز الزمني والفترة الزمنية
symbol = "EURUSD"  # على سبيل المثال
timeframe = mt5.TIMEFRAME_M15  # دقيقة واحدة
num_bars = 100  # عدد الشموع المطلوبة لحساب المؤشرات

# الحصول على البيانات من MT5
rates = mt5.copy_rates_from_pos(symbol, timeframe, 0, num_bars)



# تحويل البيانات إلى DataFrame
if rates is None or len(rates) == 0:
    print("No data received from MT5")
else:
    rates_df = pd.DataFrame(rates)

    # حساب المؤشرات الفنية باستخدام pandas-ta
    rates_df['EMA_100'] = ta.ema(rates_df['close'], length=100)
    rates_df['EMA_50'] = ta.ema(rates_df['close'], length=50)
    rates_df['EMA_21'] = ta.ema(rates_df['close'], length=21)
    rates_df['EMA_13'] = ta.ema(rates_df['close'], length=13)
    rates_df['EMA_7'] = ta.ema(rates_df['close'], length=7)
    rates_df['RSI_10'] = ta.rsi(rates_df['close'], length=10)
    rates_df['ATR_10'] = ta.atr(rates_df['high'], rates_df['low'], rates_df['close'], length=10)
    rates_df['ATR_30'] = ta.atr(rates_df['high'], rates_df['low'], rates_df['close'], length=30)

    # اختيار آخر صف للمدخلات
    input_data = rates_df.iloc[-1][['open', 'high', 'low', 'close', 'tick_volume',
                                    'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                                    'RSI_10', 'ATR_10', 'ATR_30']]

    # تحويل المدخلات إلى DataFrame
    input_df = pd.DataFrame([input_data])

    # التأكد من ترتيب الأعمدة كما في التدريب
    features = ['open', 'high', 'low', 'close', 'tick_volume',
                'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                'RSI_10', 'ATR_10', 'ATR_30']

    # ترتيب الأعمدة كما في التدريب
    input_df = input_df[features]




# فرضاً أن prediction_ هو مصفوفة NumPy تحتوي على قيمة واحدة
    prediction_ = model.predict(input_df)

# استخراج القيمة من المصفوفة إذا كانت تحتوي على عنصر واحد
    prediction_value = prediction_[0]

# تنسيق الرقم إلى 5 خانات عشرية
    formatted_prediction = "{:.5f}".format(prediction_value)

    print(f'التنبؤ: {formatted_prediction}')


#--------------------------------------------------------------
symbol = "EURUSD"  # تغيير الرمز كما يلزم
lot_size = 0.10  # حجم العقد
X = formatted_prediction  # مستوى السعر الذي ستقارن به
T = formatted_prediction  # الهدف (مثلاً 50 نقطة)
X = float(X)  # تحويل X إلى float إذا كان سلسلة نصية
T = float(T)  

S = 90  # وقف الخسارة (مثلاً 30 نقطة)

# الحصول على سعر السوق الحالي
symbol_info = mt5.symbol_info(symbol)
if symbol_info is None:
    print(f"الرمز {symbol} غير متوفر")
    mt5.shutdown()
    exit()

# التأكد من أن السوق جاهز للتداول
if not symbol_info.visible:
    print(f"الرمز {symbol} غير مرئي، سيتم فتحه...")
    mt5.symbol_select(symbol, True)

# الحصول على أسعار السوق الحالية
price = mt5.symbol_info_tick(symbol).ask  # سعر الشراء
print(f"السعر الحالي للشراء {price}")

# تحديد نوع الصفقة بناءً على الشروط
if price > X:
    order_type = mt5.ORDER_TYPE_BUY
    order_price = price
    print(f"فتح صفقة شراء عند السعر {order_price}")
else:
    order_type = mt5.ORDER_TYPE_SELL
    order_price = mt5.symbol_info_tick(symbol).bid  # سعر البيع
    print(f"فتح صفقة بيع عند السعر {order_price}")

# إعداد مستويات وقف الخسارة وهدف الربح
point = mt5.symbol_info(symbol).point
if order_type == mt5.ORDER_TYPE_BUY:
    sl = order_price - S * point  # وقف الخسارة
    tp = order_price + T * point  # هدف الربح
else:
    sl = order_price + S * point  # وقف الخسارة
    tp = order_price - T * point  # هدف الربح

# إعداد الطلب
order_request = {
    "action": mt5.TRADE_ACTION_DEAL,
    "symbol": symbol,
    "volume": lot_size,
    "type": order_type,
    "price": order_price,
    "sl": sl,
    "tp": tp,
    "deviation": 30,
    "magic": 234000,
    "comment": "Python script open",
    "type_time": mt5.ORDER_TIME_GTC,  # Good till cancelled
    "type_filling": mt5.ORDER_FILLING_IOC,
}

# تنفيذ الصفقة
result = mt5.order_send(order_request)

# التحقق من نتيجة الطلب
if result.retcode != mt5.TRADE_RETCODE_DONE:
    print(f"فشل في فتح الصفقة، الخطأ: {result.retcode}")
else:
    print(f"تم فتح الصفقة بنجاح: {result}")


# التأكد من إغلاق الاتصال بـ MetaTrader 5
mt5.shutdown()
# Out:
# التنبؤ: 1.07838
# السعر الحالي للشراء 1.0783800000000001
# فتح صفقة شراء عند السعر 1.0783800000000001
# فشل في فتح الصفقة، الخطأ: 10027
# True

# %%
# استيراد المكتبات اللازمة
import pandas as pd
import lightgbm as lgb
import MetaTrader5 as mt5
import pandas_ta as ta
import numpy as np
import pyfiglet as pf

textArt = pf.figlet_format("F-14 >>>>>\n POWER OF AI")
print(textArt)

print("#--------------------------------------------------------------------# ")    

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# معلومات تسجيل الدخول
account_number = 51915724  # رقم الحساب
password = "yqWAA@pt37$V1W"  # كلمة المرور
server = "ICMarketsSC-Demo"  # اسم الخادم

# تهيئة الاتصال بـ MetaTrader 5
if not mt5.initialize(login=account_number, password=password, server=server):
    print("[!] error in connect to MT5.")
    mt5.shutdown()

# تحديد الرمز الزمني والفترة الزمنية
symbol = "EURUSD"  # على سبيل المثال
timeframe = mt5.TIMEFRAME_M1  # دقيقة واحدة
num_bars = 100  # عدد الشموع المطلوبة لحساب المؤشرات

# الحصول على البيانات من MT5
rates = mt5.copy_rates_from_pos(symbol, timeframe, 0, num_bars)

# تحويل البيانات إلى DataFrame
if rates is None or len(rates) == 0:
    print("[!] no data from mt5.")
    print("#--------------------------------------------------------------------# ")    

else:
    rates_df = pd.DataFrame(rates)

    # حساب المؤشرات الفنية باستخدام pandas-ta
    rates_df['EMA_100'] = ta.ema(rates_df['close'], length=100)
    rates_df['EMA_50'] = ta.ema(rates_df['close'], length=50)
    rates_df['EMA_21'] = ta.ema(rates_df['close'], length=21)
    rates_df['EMA_13'] = ta.ema(rates_df['close'], length=13)
    rates_df['EMA_7'] = ta.ema(rates_df['close'], length=7)
    rates_df['RSI_10'] = ta.rsi(rates_df['close'], length=10)
    rates_df['ATR_10'] = ta.atr(rates_df['high'], rates_df['low'], rates_df['close'], length=10)
    rates_df['ATR_30'] = ta.atr(rates_df['high'], rates_df['low'], rates_df['close'], length=30)

    # اختيار آخر صف للمدخلات
    input_data = rates_df.iloc[-1][['open', 'high', 'low', 'close', 'tick_volume',
                                    'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                                    'RSI_10', 'ATR_10', 'ATR_30']]

    # تحويل المدخلات إلى DataFrame
    input_df = pd.DataFrame([input_data])

    # التأكد من ترتيب الأعمدة كما في التدريب
    features = ['open', 'high', 'low', 'close', 'tick_volume',
                'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                'RSI_10', 'ATR_10', 'ATR_30']

    # ترتيب الأعمدة كما في التدريب
    input_df = input_df[features]

    # فرضاً أن prediction_ هو مصفوفة NumPy تحتوي على قيمة واحدة
    prediction_ = model.predict(input_df)

    # استخراج القيمة من المصفوفة إذا كانت تحتوي على عنصر واحد
    prediction_value = prediction_[0]

    # تنسيق الرقم إلى 5 خانات عشرية
    formatted_prediction = "{:.5f}".format(prediction_value)
    print(f'# Prediction: {formatted_prediction}')

# إعداد معلومات الصفقة
symbol = "EURUSD"  # تغيير الرمز كما يلزم
lot_size = 0.1  # حجم العقد
X = float(formatted_prediction)  # مستوى السعر الذي ستقارن به
T = X   # الهدف (مثلاً 50 نقطة)
S = 10  # وقف الخسارة (مثلاً 30 نقطة)

# الحصول على سعر السوق الحالي
symbol_info = mt5.symbol_info(symbol)
if symbol_info is None:
    print(f"[!] Symbol {symbol} is unavailable")
    mt5.shutdown()
    exit()

# التأكد من أن السوق جاهز للتداول
if not symbol_info.visible:
    print(f"الرمز {symbol} غير مرئي، سيتم فتحه...")
    mt5.symbol_select(symbol, True)

# الحصول على أسعار السوق الحالية
tick_info = mt5.symbol_info_tick(symbol)
if tick_info is None:
    print(f"[!] Failed to get prices for [{symbol}] symbol.")
    mt5.shutdown()
    exit()

ask_price = tick_info.ask  # سعر الشراء
bid_price = tick_info.bid  # سعر البيع
print(f"# Ask    ---> {ask_price}")
print(f"# Bid    ---> {bid_price}")
print(f"# Spread ---> {ask_price - bid_price}")

# تحديد نوع الصفقة بناءً على الشروط
if ask_price < X:
    order_type = mt5.ORDER_TYPE_BUY
    order_price = ask_price
    print(f"# Buy order at {order_price}")
else:
    order_type = mt5.ORDER_TYPE_SELL
    order_price = bid_price  # سعر البيع
    print(f"# Sell order at {order_price}")

# إعداد مستويات وقف الخسارة وهدف الربح
point = mt5.symbol_info(symbol).point
if order_type == mt5.ORDER_TYPE_BUY:
    sl = order_price - S * point  # وقف الخسارة
    #tp = order_price + T * point  # هدف الربح
    tp = T   # هدف الربح

else:
    sl = order_price + S * point  # وقف الخسارة
    #tp = order_price - T * point  # هدف الربح
    tp = T   # هدف الربح

# إعداد الطلب
order_request = {
    "action": mt5.TRADE_ACTION_DEAL,
    "symbol": symbol,
    "volume": lot_size,
    "type": order_type,
    "price": order_price,  # تأكد من تحديد السعر الصحيح
    "sl": sl,
    "tp": tp,
    "deviation": 30,
    "magic": 234000,
    "comment": "Python script open",
    "type_time": mt5.ORDER_TIME_GTC,
    "type_filling": mt5.ORDER_FILLING_IOC,
}

# تنفيذ الصفقة
result = mt5.order_send(order_request)

# التحقق من نتيجة الطلب
if result is None:
    print("فشل في إرسال الطلب")
    print(f"[!] last error: {mt5.last_error()}")
    mt5.shutdown()
    exit()

if result.retcode != mt5.TRADE_RETCODE_DONE:
    print("#--------------------------------------------------------------------# ")    
    print(f"[!] cant open order, error is: {result.retcode}")    
    # طباعة معلومات إضافية حول الخطأ
    print(f"[!] more error details: {result}")
    print("#--------------------------------------------------------------------# ")    

else:
    print("#--------------------------------------------------------------------# ")    
    print(f"# the order has been opened seccessfully.")


from datetime import datetime
import time
import os
import sys


# دالة لتحويل وقت Unix إلى وقت مقروء
def unix_to_datetime(unix_time):
    return datetime.fromtimestamp(unix_time).strftime('%Y-%m-%d %H:%M:%S')

# دالة لمسح الشاشة بطريقة بديلة باستخدام sys.stdout.write
def clear_screen():
    sys.stdout.write("\033[H\033[J")  # مسح الشاشة باستخدام ANSI

# دالة لمراقبة الصفقات المفتوحة
def monitor_trades():
    while True:
        clear_screen()  # مسح الشاشة قبل الطباعة الجديدة

        positions = mt5.positions_get()
        if positions:
            print("\n--- Open Positions ---")
            for position in positions:
                print(f"Symbol: {position.symbol}")
                print(f"Ticket: {position.ticket}")
                # تم إزالة print(f"Order ID: {position.order}") بسبب عدم وجود الخاصية
                print(f"Volume: {position.volume}")
                print(f"Type: {'Buy' if position.type == 0 else 'Sell'}")
                print(f"Open Price: {position.price_open}")
                print(f"Stop Loss: {position.sl}")
                print(f"Take Profit: {position.tp}")
                print(f"Profit: {position.profit}")
                print(f"Swap: {position.swap}")
                print(f"Magic Number: {position.magic}")
                print(f"Open Time: {unix_to_datetime(position.time)}")
                print(f"Last Update Time: {unix_to_datetime(position.time_update)}")
                print(f"---\n")
        else:
            print("No open positions.")

        # الانتظار لعدد معين من الثواني قبل التحديث
        time.sleep(5)

# بدء مراقبة الصفقات
monitor_trades()
# التأكد من إغلاق الاتصال بـ MetaTrader 5
#mt5.shutdown()
# Out:
#  _____     _ _  _    __________
# |  ___|   / | || |   \ \ \ \ \ \
# | |_ _____| | || |_   \ \ \ \ \ \
# |  _|_____| |__   _|  / / / / / /
# |_|       |_|  |_|   /_/_/_/_/_/
#
#   ____   _____        _______ ____     ___  _____      _    ___
#  |  _ \ / _ \ \      / / ____|  _ \   / _ \|  ___|    / \  |_ _|
#  | |_) | | | \ \ /\ / /|  _| | |_) | | | | | |_      / _ \  | |
#  |  __/| |_| |\ V  V / | |___|  _ <  | |_| |  _|    / ___ \ | |
#  |_|    \___/  \_/\_/  |_____|_| \_\  \___/|_|     /_/   \_\___|
#
#
# #--------------------------------------------------------------------#
# # Prediction: 1.08205
# # Ask    ---> 1.0820400000000001
# # Bid    ---> 1.0820400000000001
# # Spread ---> 0.0
# # Buy order at 1.0820400000000001
# #--------------------------------------------------------------------#
# # the order has been opened seccessfully.
#
# --- Open Positions ---
# Symbol: EURUSD
# Ticket: 801665925
# Volume: 0.1
# Type: Buy
# Open Price: 1.08209
# Stop Loss: 1.08183
# ...

# %%
import pandas as pd
import lightgbm as lgb
import MetaTrader5 as mt5
import pandas_ta as ta
import time

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# معلومات تسجيل الدخول
account_number = 51915724  # رقم الحساب
password = "yqWAA@pt37$V1W"  # كلمة المرور
server = "ICMarketsSC-Demo"  # اسم الخادم

# تهيئة الاتصال بـ MetaTrader 5
if not mt5.initialize(login=account_number, password=password, server=server):
    print("Failed to initialize MT5")
    mt5.shutdown()

# تحديد الرمز الزمني
symbol = "EURUSD"  # على سبيل المثال

try:
    while True:
        # الحصول على البيانات من MT5
        ticks = mt5.copy_ticks_from(symbol, time.time() - 60, 100, mt5.COPY_TICKS_ALL)

        # تحويل البيانات إلى DataFrame
        if ticks is not None and len(ticks) > 0:
            ticks_df = pd.DataFrame(ticks)

            # التأكد من وجود عدد كافٍ من التِك
            if len(ticks_df) >= 3:
                # تقسيم التِك إلى مجموعات من 3
                grouped_ticks = ticks_df.groupby(ticks_df.index // 3)

                # حساب القيم المفتوحة، العالية، المنخفضة، والإغلاق لكل مجموعة
                ohlc = grouped_ticks['last'].agg({
                    'open': 'first',
                    'high': 'max',
                    'low': 'min',
                    'close': 'last'
                })

                # إضافة الحجم (volume) كميزة
                ohlc['tick_volume'] = grouped_ticks['volume'].sum()

                # حساب المؤشرات الفنية باستخدام pandas-ta
                ohlc['EMA_100'] = ta.ema(ohlc['close'], length=100)
                ohlc['EMA_50'] = ta.ema(ohlc['close'], length=50)
                ohlc['EMA_21'] = ta.ema(ohlc['close'], length=21)
                ohlc['EMA_13'] = ta.ema(ohlc['close'], length=13)
                ohlc['EMA_7'] = ta.ema(ohlc['close'], length=7)
                ohlc['RSI_10'] = ta.rsi(ohlc['close'], length=10)
                ohlc['ATR_10'] = ta.atr(ohlc['high'], ohlc['low'], ohlc['close'], length=10)
                ohlc['ATR_30'] = ta.atr(ohlc['high'], ohlc['low'], ohlc['close'], length=30)

                # اختيار آخر صف للمدخلات
                input_data = ohlc.iloc[-1][[
                    'open', 'high', 'low', 'close', 'tick_volume',
                    'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                    'RSI_10', 'ATR_10', 'ATR_30'
                ]]

                # تحويل المدخلات إلى DataFrame
                input_df = pd.DataFrame([input_data])

                # التأكد من ترتيب الأعمدة كما في التدريب
                features = [
                    'open', 'high', 'low', 'close', 'tick_volume',
                    'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                    'RSI_10', 'ATR_10', 'ATR_30'
                ]

                # ترتيب الأعمدة كما في التدريب
                input_df = input_df[features]

                # التنبؤ باستخدام النموذج
                prediction = model.predict(input_df)

                # عرض النتيجة
                print(f'التنبؤ: {prediction[0]}')

        # الانتظار لبضع ثوانٍ قبل التحديث مرة أخرى
        time.sleep(1)  # انتظر 1 ثانية (يمكنك ضبط الوقت حسب الحاجة)

finally:
    # التأكد من إغلاق الاتصال بـ MetaTrader 5
    mt5.shutdown()
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# Cell In[17], line 38
#      35 grouped_ticks = ticks_df.groupby(ticks_df.index // 3)
#      37 # حساب القيم المفتوحة، العالية، المنخفضة، والإغلاق لكل مجموعة
# ---> 38 ohlc = grouped_ticks['last'].agg({
#      39     'open': 'first',
#      40     'high': 'max',
#      41     'low': 'min',
#      42     'close': 'last'
#      43 })
#      45 # إضافة الحجم (volume) كميزة
#      46 ohlc['tick_volume'] = grouped_ticks['volume'].sum()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:257, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     255 kwargs["engine"] = engine
#     256 kwargs["engine_kwargs"] = engine_kwargs
# --> 257 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     258 if relabeling:
# ...

# %%
import pandas as pd
import lightgbm as lgb
import MetaTrader5 as mt5
import pandas_ta as ta
import time

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# معلومات تسجيل الدخول
account_number = 51915724  # رقم الحساب
password = "yqWAA@pt37$V1W"  # كلمة المرور
server = "ICMarketsSC-Demo"  # اسم الخادم

# تهيئة الاتصال بـ MetaTrader 5
if not mt5.initialize(login=account_number, password=password, server=server):
    print("Failed to initialize MT5")
    mt5.shutdown()

# تحديد الرمز الزمني
symbol = "EURUSD"  # على سبيل المثال

try:
    while True:
        # الحصول على البيانات من MT5
        ticks = mt5.copy_ticks_from(symbol, time.time() - 60, 100, mt5.COPY_TICKS_ALL)

        # تحويل البيانات إلى DataFrame
        if ticks is not None and len(ticks) > 0:
            ticks_df = pd.DataFrame(ticks)

            # التأكد من وجود عدد كافٍ من التِك
            if len(ticks_df) >= 3:
                # تقسيم التِك إلى مجموعات من 3
                grouped_ticks = ticks_df.groupby(ticks_df.index // 3)

                # حساب القيم المفتوحة، العالية، المنخفضة، والإغلاق لكل مجموعة
                ohlc = grouped_ticks['last'].agg(['first', 'max', 'min', 'last'])
                ohlc.columns = ['open', 'high', 'low', 'close']

                # إضافة الحجم (volume) كميزة
                ohlc['tick_volume'] = grouped_ticks['volume'].sum()

                # حساب المؤشرات الفنية باستخدام pandas-ta
                ohlc['EMA_100'] = ta.ema(ohlc['close'], length=100)
                ohlc['EMA_50'] = ta.ema(ohlc['close'], length=50)
                ohlc['EMA_21'] = ta.ema(ohlc['close'], length=21)
                ohlc['EMA_13'] = ta.ema(ohlc['close'], length=13)
                ohlc['EMA_7'] = ta.ema(ohlc['close'], length=7)
                ohlc['RSI_10'] = ta.rsi(ohlc['close'], length=10)
                ohlc['ATR_10'] = ta.atr(ohlc['high'], ohlc['low'], ohlc['close'], length=10)
                ohlc['ATR_30'] = ta.atr(ohlc['high'], ohlc['low'], ohlc['close'], length=30)

                # اختيار آخر صف للمدخلات
                input_data = ohlc.iloc[-1][[
                    'open', 'high', 'low', 'close', 'tick_volume',
                    'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                    'RSI_10', 'ATR_10', 'ATR_30'
                ]]

                # تحويل المدخلات إلى DataFrame
                input_df = pd.DataFrame([input_data])

                # التأكد من ترتيب الأعمدة كما في التدريب
                features = [
                    'open', 'high', 'low', 'close', 'tick_volume',
                    'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                    'RSI_10', 'ATR_10', 'ATR_30'
                ]

                # ترتيب الأعمدة كما في التدريب
                input_df = input_df[features]

                # التنبؤ باستخدام النموذج
                prediction = model.predict(input_df)

                # عرض النتيجة
                print(f'التنبؤ: {prediction[0]}')

        # الانتظار لبضع ثوانٍ قبل التحديث مرة أخرى
        time.sleep(1)  # انتظر 1 ثانية (يمكنك ضبط الوقت حسب الحاجة)

finally:
    # التأكد من إغلاق الاتصال بـ MetaTrader 5
    mt5.shutdown()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 75
#      72 input_df = input_df[features]
#      74 # التنبؤ باستخدام النموذج
# ---> 75 prediction = model.predict(input_df)
#      77 # عرض النتيجة
#      78 print(f'التنبؤ: {prediction[0]}')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\lightgbm\basic.py:4748, in Booster.predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features, **kwargs)
#    4746     else:
#    4747         num_iteration = -1
# -> 4748 return predictor.predict(
#    4749     data=data,
#    4750     start_iteration=start_iteration,
#    4751     num_iteration=num_iteration,
#    4752     raw_score=raw_score,
#    4753     pred_leaf=pred_leaf,
#    4754     pred_contrib=pred_contrib,
#    4755     data_has_header=data_has_header,
# ...

# %%
import pandas as pd
import lightgbm as lgb
import MetaTrader5 as mt5
import pandas_ta as ta
import time

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# معلومات تسجيل الدخول
account_number = 51915724  # رقم الحساب
password = "yqWAA@pt37$V1W"  # كلمة المرور
server = "ICMarketsSC-Demo"  # اسم الخادم

# تهيئة الاتصال بـ MetaTrader 5
if not mt5.initialize(login=account_number, password=password, server=server):
    print("Failed to initialize MT5")
    mt5.shutdown()

# تحديد الرمز الزمني
symbol = "EURUSD"  # على سبيل المثال

try:
    while True:
        # الحصول على البيانات من MT5
        ticks = mt5.copy_ticks_from(symbol, time.time() - 60, 100, mt5.COPY_TICKS_ALL)

        # تحويل البيانات إلى DataFrame
        if ticks is not None and len(ticks) > 0:
            ticks_df = pd.DataFrame(ticks)

            # التأكد من وجود عدد كافٍ من التِك
            if len(ticks_df) >= 3:
                # تقسيم التِك إلى مجموعات من 3
                grouped_ticks = ticks_df.groupby(ticks_df.index // 3)

                # حساب القيم المفتوحة، العالية، المنخفضة، والإغلاق لكل مجموعة
                ohlc = grouped_ticks['last'].agg(['first', 'max', 'min', 'last'])
                ohlc.columns = ['open', 'high', 'low', 'close']

                # إضافة الحجم (volume) كميزة
                ohlc['tick_volume'] = grouped_ticks['volume'].sum()

                # حساب المؤشرات الفنية باستخدام pandas-ta
                ohlc['EMA_100'] = ta.ema(ohlc['close'], length=100)
                ohlc['EMA_50'] = ta.ema(ohlc['close'], length=50)
                ohlc['EMA_21'] = ta.ema(ohlc['close'], length=21)
                ohlc['EMA_13'] = ta.ema(ohlc['close'], length=13)
                ohlc['EMA_7'] = ta.ema(ohlc['close'], length=7)
                ohlc['RSI_10'] = ta.rsi(ohlc['close'], length=10)
                ohlc['ATR_10'] = ta.atr(ohlc['high'], ohlc['low'], ohlc['close'], length=10)
                ohlc['ATR_30'] = ta.atr(ohlc['high'], ohlc['low'], ohlc['close'], length=30)

                # اختيار آخر صف للمدخلات
                input_data = ohlc.iloc[-1][[
                    'open', 'high', 'low', 'close', 'tick_volume',
                    'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                    'RSI_10', 'ATR_10', 'ATR_30'
                ]]

                # تحويل المدخلات إلى DataFrame
                input_df = pd.DataFrame([input_data])

                # ملء القيم المفقودة وتحويل القيم إلى النوع العائم
                input_df = input_df.fillna(0).astype(float)

                # التأكد من ترتيب الأعمدة كما في التدريب
                features = [
                    'open', 'high', 'low', 'close', 'tick_volume',
                    'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                    'RSI_10', 'ATR_10', 'ATR_30'
                ]

                # ترتيب الأعمدة كما في التدريب
                input_df = input_df[features]

                # التنبؤ باستخدام النموذج
                prediction = model.predict(input_df)

                # عرض النتيجة
                print(f'التنبؤ: {prediction[0]}')

        # الانتظار لبضع ثوانٍ قبل التحديث مرة أخرى
        time.sleep(1)  # انتظر 1 ثانية (يمكنك ضبط الوقت حسب الحاجة)

finally:
    # التأكد من إغلاق الاتصال بـ MetaTrader 5
    mt5.shutdown()
# Out:
# C:\Users\Access\AppData\Local\Temp\ipykernel_14540\805377872.py:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   input_df = input_df.fillna(0).astype(float)
# التنبؤ: 1.0616676949860957
# C:\Users\Access\AppData\Local\Temp\ipykernel_14540\805377872.py:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   input_df = input_df.fillna(0).astype(float)
# التنبؤ: 1.0616676949860957
# ...

# %%
import requests

# URL الخاص بـ cTrader Open API
url = "https://api.spotware.com/some_endpoint"

# مفتاح API الخاص بك
headers = {
    'Authorization': '12063_H9AEW0UKNXCY9zkUMVZ6ikKRyRzkS4HflhEfTAe7M1GnPyRDrm',
    'Content-Type': 'XD25AP1bl0Ssmm8sKKXS3cxoTcws2SY4Li5k3wrxcpY3uOl5z7'
}

# البيانات الخاصة بالطلب، مثل أوامر الشراء/البيع
data = {
    'symbol': 'EURUSD',
    'orderType': 'BUY',
    'volume': 100000  # على سبيل المثال
}

# إرسال الطلب عبر HTTP POST
response = requests.post(url, headers=headers, json=data)

# عرض النتيجة
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\ProgramData\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
import requests
import pandas as pd
import lightgbm as lgb
import pandas_ta as ta

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# معلومات العميل
CLIENT_ID = "12063_H9AEW0UKNXCY9zkUMVZ6ikKRyRzkS4HflhEfTAe7M1GnPyRDrm"
CLIENT_SECRET = "XD25AP1bl0Ssmm8sKKXS3cxoTcws2SY4Li5k3wrxcpY3uOl5z7"

# الحصول على Access Token
def get_access_token(client_id, client_secret):
    url = "https://connect.spotware.com/oauth2/token"
    payload = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret
    }
    
    response = requests.post(url, data=payload)
    if response.status_code == 200:
        return response.json().get("access_token")
    else:
        print("Error:", response.json())
        return None

# استخدام Access Token للحصول على بيانات الـ "ticks"
def get_tick_data(access_token, symbol, count):
    url = f"https://api.spotware.com/connect/tradingaccounts/{symbol}/ticks?count={count}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Error:", response.json())
        return None

# تجميع كل 3 ticks إلى شمعة واحدة
def aggregate_ticks_to_candles(ticks_df):
    # تقسيم البيانات إلى مجموعات كل 3 ticks
    ticks_df['group'] = (ticks_df.index // 3)
    
    # تجميع البيانات للحصول على open, high, low, close, volume
    candles = ticks_df.groupby('group').agg({
        'price': ['first', 'max', 'min', 'last'],
        'volume': 'sum'
    })
    
    candles.columns = ['open', 'high', 'low', 'close', 'tick_volume']
    candles.dropna(inplace=True)  # إزالة أي صفوف تحتوي على قيم مفقودة
    
    return candles

# تنفيذ الوظائف
if __name__ == "__main__":
    access_token = get_access_token(CLIENT_ID, CLIENT_SECRET)
    if access_token:
        symbol = "EURUSD"  # رمز الزوج
        count = 300  # عدد الـ "ticks" المطلوبة للحصول على 100 شمعات (3 ticks لكل شمعة)

        # الحصول على بيانات الـ "ticks"
        tick_data = get_tick_data(access_token, symbol, count)
        if tick_data:
            # تحويل البيانات إلى DataFrame
            ticks_df = pd.DataFrame(tick_data['ticks'])

            # تجميع الـ "ticks" إلى شموع
            candles_df = aggregate_ticks_to_candles(ticks_df)

            # حساب المؤشرات الفنية باستخدام pandas-ta
            candles_df['EMA_100'] = ta.ema(candles_df['close'], length=100)
            candles_df['EMA_50'] = ta.ema(candles_df['close'], length=50)
            candles_df['EMA_21'] = ta.ema(candles_df['close'], length=21)
            candles_df['EMA_13'] = ta.ema(candles_df['close'], length=13)
            candles_df['EMA_7'] = ta.ema(candles_df['close'], length=7)
            candles_df['RSI_10'] = ta.rsi(candles_df['close'], length=10)
            candles_df['ATR_10'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=10)
            candles_df['ATR_30'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=30)

            # اختيار آخر صف للمدخلات
            input_data = candles_df.iloc[-1][['open', 'high', 'low', 'close', 'tick_volume',
                                              'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                                              'RSI_10', 'ATR_10', 'ATR_30']]

            # تحويل المدخلات إلى DataFrame
            input_df = pd.DataFrame([input_data])

            # ترتيب الأعمدة كما في التدريب
            features = ['open', 'high', 'low', 'close', 'tick_volume',
                        'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                        'RSI_10', 'ATR_10', 'ATR_30']

            # ترتيب الأعمدة كما في التدريب
            input_df = input_df[features]

            # التنبؤ باستخدام النموذج
            prediction = model.predict(input_df)

            # عرض النتيجة
            print(f'التنبؤ: {prediction[0]}')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\ProgramData\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
import requests
import pandas as pd
import lightgbm as lgb
import pandas_ta as ta

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# معلومات العميل
CLIENT_ID = "YOUR_CLIENT_ID"
CLIENT_SECRET = "YOUR_CLIENT_SECRET"

# الحصول على Access Token
def get_access_token(client_id, client_secret):
    url = "https://connect.spotware.com/oauth2/token"
    payload = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret
    }
    
    response = requests.post(url, data=payload)
    
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data.get("access_token")
        else:
            print("Error in getting access token:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# استخدام Access Token للحصول على بيانات الـ "ticks"
def get_tick_data(access_token, symbol, count):
    url = f"https://api.spotware.com/connect/tradingaccounts/{symbol}/ticks?count={count}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data
        else:
            print("Error in getting tick data:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# تجميع كل 3 ticks إلى شمعة واحدة
def aggregate_ticks_to_candles(ticks_df):
    # تقسيم البيانات إلى مجموعات كل 3 ticks
    ticks_df['group'] = (ticks_df.index // 3)
    
    # تجميع البيانات للحصول على open, high, low, close, volume
    candles = ticks_df.groupby('group').agg({
        'price': ['first', 'max', 'min', 'last'],
        'volume': 'sum'
    })
    
    candles.columns = ['open', 'high', 'low', 'close', 'tick_volume']
    candles.dropna(inplace=True)  # إزالة أي صفوف تحتوي على قيم مفقودة
    
    return candles

# تنفيذ الوظائف
if __name__ == "__main__":
    access_token = get_access_token(CLIENT_ID, CLIENT_SECRET)
    if access_token:
        symbol = "EURUSD"  # رمز الزوج
        count = 300  # عدد الـ "ticks" المطلوبة للحصول على 100 شمعات (3 ticks لكل شمعة)

        # الحصول على بيانات الـ "ticks"
        tick_data = get_tick_data(access_token, symbol, count)
        if tick_data:
            # تحويل البيانات إلى DataFrame
            ticks_df = pd.DataFrame(tick_data['ticks'])

            # تجميع الـ "ticks" إلى شموع
            candles_df = aggregate_ticks_to_candles(ticks_df)

            # حساب المؤشرات الفنية باستخدام pandas-ta
            candles_df['EMA_100'] = ta.ema(candles_df['close'], length=100)
            candles_df['EMA_50'] = ta.ema(candles_df['close'], length=50)
            candles_df['EMA_21'] = ta.ema(candles_df['close'], length=21)
            candles_df['EMA_13'] = ta.ema(candles_df['close'], length=13)
            candles_df['EMA_7'] = ta.ema(candles_df['close'], length=7)
            candles_df['RSI_10'] = ta.rsi(candles_df['close'], length=10)
            candles_df['ATR_10'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=10)
            candles_df['ATR_30'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=30)

            # اختيار آخر صف للمدخلات
            input_data = candles_df.iloc[-1][['open', 'high', 'low', 'close', 'tick_volume',
                                              'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                                              'RSI_10', 'ATR_10', 'ATR_30']]

            # تحويل المدخلات إلى DataFrame
            input_df = pd.DataFrame([input_data])

            # ترتيب الأعمدة كما في التدريب
            features = ['open', 'high', 'low', 'close', 'tick_volume',
                        'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                        'RSI_10', 'ATR_10', 'ATR_30']

            # ترتيب الأعمدة كما في التدريب
            input_df = input_df[features]

            # التنبؤ باستخدام النموذج
            prediction = model.predict(input_df)

            # عرض النتيجة
            print(f'التنبؤ: {prediction[0]}')
# Out:
# Failed to decode JSON. Response text: <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#
#         <title>Not Found</title>
#
#         <style>
# ...

# %%
import requests
import pandas as pd
import lightgbm as lgb
import pandas_ta as ta

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# معلومات العميل
CLIENT_ID = "12063_H9AEW0UKNXCY9zkUMVZ6ikKRyRzkS4HflhEfTAe7M1GnPyRDrm"
CLIENT_SECRET = "XD25AP1bl0Ssmm8sKKXS3cxoTcws2SY4Li5k3wrxcpY3uOl5z7"

# الحصول على Access Token
def get_access_token(client_id, client_secret):
    url = "https://connect.spotware.com/oauth2/token"
    payload = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret
    }
    
    response = requests.post(url, data=payload)
    
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data.get("access_token")
        else:
            print("Error in getting access token:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# استخدام Access Token للحصول على بيانات الـ "ticks"
def get_tick_data(access_token, symbol, count):
    url = f"https://api.spotware.com/connect/tradingaccounts/{symbol}/ticks?count={count}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data
        else:
            print("Error in getting tick data:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# جلب قائمة الحسابات
def get_accounts(access_token):
    url = "https://api.spotware.com/connect/tradingaccounts"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data['accounts']
        else:
            print("Error in getting accounts:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# تجميع كل 3 ticks إلى شمعة واحدة
def aggregate_ticks_to_candles(ticks_df):
    ticks_df['group'] = (ticks_df.index // 3)
    candles = ticks_df.groupby('group').agg({
        'price': ['first', 'max', 'min', 'last'],
        'volume': 'sum'
    })
    candles.columns = ['open', 'high', 'low', 'close', 'tick_volume']
    candles.dropna(inplace=True)
    return candles

# تنفيذ الوظائف
if __name__ == "__main__":
    access_token = get_access_token(CLIENT_ID, CLIENT_SECRET)
    if access_token:
        # جلب الحسابات المتاحة
        accounts = get_accounts(access_token)
        if accounts:
            print("Available accounts:")
            for account in accounts:
                print(f"Account ID: {account['id']}, Broker: {account['brokerName']}")

            # تحديد معرف الحساب الذي ترغب في التداول عليه
            selected_account_id = 'YOUR_SELECTED_ACCOUNT_ID'
            print(f"Selected account ID: {selected_account_id}")

            symbol = "EURUSD"
            count = 300

            # الحصول على بيانات الـ "ticks"
            tick_data = get_tick_data(access_token, symbol, count)
            if tick_data:
                ticks_df = pd.DataFrame(tick_data['ticks'])
                candles_df = aggregate_ticks_to_candles(ticks_df)

                # حساب المؤشرات الفنية باستخدام pandas-ta
                candles_df['EMA_100'] = ta.ema(candles_df['close'], length=100)
                candles_df['EMA_50'] = ta.ema(candles_df['close'], length=50)
                candles_df['EMA_21'] = ta.ema(candles_df['close'], length=21)
                candles_df['EMA_13'] = ta.ema(candles_df['close'], length=13)
                candles_df['EMA_7'] = ta.ema(candles_df['close'], length=7)
                candles_df['RSI_10'] = ta.rsi(candles_df['close'], length=10)
                candles_df['ATR_10'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=10)
                candles_df['ATR_30'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=30)

                input_data = candles_df.iloc[-1][['open', 'high', 'low', 'close', 'tick_volume',
                                                  'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                                                  'RSI_10', 'ATR_10', 'ATR_30']]

                input_df = pd.DataFrame([input_data])
                features = ['open', 'high', 'low', 'close', 'tick_volume',
                            'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                            'RSI_10', 'ATR_10', 'ATR_30']
                input_df = input_df[features]

                prediction = model.predict(input_df)
                print(f"Prediction: {prediction[0]}")

                # تنفيذ أمر تداول بناءً على التنبؤ
                if prediction[0] > 0.5:  # مثال على شرط لتنفيذ أمر شراء
                    print("Placing a buy order...")
                    # هنا يمكنك إضافة الكود لتنفيذ الأمر باستخدام API الخاصة بـ Spotware
# Out:
# Failed to decode JSON. Response text: <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#
#         <title>Not Found</title>
#
#         <style>
# ...

# %%
import requests
import pandas as pd
import lightgbm as lgb
import pandas_ta as ta
import pyfiglet as pf

textArt = pf.figlet_format("F-14 >>>>>\n POWER OF AI")
print(textArt)

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# طلب إدخال Access Token من المستخدم
access_token = input("Enter your Access Token: ")

# استخدام Access Token للحصول على بيانات الـ "ticks"
def get_tick_data(access_token, symbol, count):
    url = f"https://api.spotware.com/connect/tradingaccounts/{symbol}/ticks?count={count}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data
        else:
            print("Error in getting tick data:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# جلب قائمة الحسابات
def get_accounts(access_token):
    url = "https://api.spotware.com/connect/tradingaccounts"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data['accounts']
        else:
            print("Error in getting accounts:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# تجميع كل 3 ticks إلى شمعة واحدة
def aggregate_ticks_to_candles(ticks_df):
    ticks_df['group'] = (ticks_df.index // 3)
    candles = ticks_df.groupby('group').agg({
        'price': ['first', 'max', 'min', 'last'],
        'volume': 'sum'
    })
    candles.columns = ['open', 'high', 'low', 'close', 'tick_volume']
    candles.dropna(inplace=True)
    return candles

# تنفيذ الوظائف
if __name__ == "__main__":
    if access_token:
        # جلب الحسابات المتاحة
        accounts = get_accounts(access_token)
        if accounts:
            print("Available accounts:")
            for account in accounts:
                print(f"Account ID: {account['id']}, Broker: {account['brokerName']}")

            # تحديد معرف الحساب الذي ترغب في التداول عليه
            selected_account_id = input("Enter the Account ID to trade on: ")
            symbol = "EURUSD"
            count = 300

            # الحصول على بيانات الـ "ticks"
            tick_data = get_tick_data(access_token, symbol, count)
            if tick_data:
                ticks_df = pd.DataFrame(tick_data['ticks'])
                candles_df = aggregate_ticks_to_candles(ticks_df)

                # حساب المؤشرات الفنية باستخدام pandas-ta
                candles_df['EMA_100'] = ta.ema(candles_df['close'], length=100)
                candles_df['EMA_50'] = ta.ema(candles_df['close'], length=50)
                candles_df['EMA_21'] = ta.ema(candles_df['close'], length=21)
                candles_df['EMA_13'] = ta.ema(candles_df['close'], length=13)
                candles_df['EMA_7'] = ta.ema(candles_df['close'], length=7)
                candles_df['RSI_10'] = ta.rsi(candles_df['close'], length=10)
                candles_df['ATR_10'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=10)
                candles_df['ATR_30'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=30)

                input_data = candles_df.iloc[-1][['open', 'high', 'low', 'close', 'tick_volume',
                                                  'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                                                  'RSI_10', 'ATR_10', 'ATR_30']]

                input_df = pd.DataFrame([input_data])
                features = ['open', 'high', 'low', 'close', 'tick_volume',
                            'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                            'RSI_10', 'ATR_10', 'ATR_30']
                input_df = input_df[features]

                # التنبؤ باستخدام النموذج
                prediction = model.predict(input_df)
                print(f"Prediction: {prediction[0]}")

                # تنفيذ أمر تداول بناءً على التنبؤ
                if prediction[0] > 0.5:  # مثال على شرط لتنفيذ أمر شراء
                    print("Placing a buy order...")
                    # هنا يمكنك إضافة الكود لتنفيذ الأمر باستخدام API الخاصة بـ Spotware
            else:
                print("Failed to get tick data.")
        else:
            print("Failed to get accounts.")
    else:
        print("Access Token is required.")
# Out:
#  _____     _ _  _    __________
# |  ___|   / | || |   \ \ \ \ \ \
# | |_ _____| | || |_   \ \ \ \ \ \
# |  _|_____| |__   _|  / / / / / /
# |_|       |_|  |_|   /_/_/_/_/_/
#
#   ____   _____        _______ ____     ___  _____      _    ___
#  |  _ \ / _ \ \      / / ____|  _ \   / _ \|  ___|    / \  |_ _|
#  | |_) | | | \ \ /\ / /|  _| | |_) | | | | | |_      / _ \  | |
#  |  __/| |_| |\ V  V / | |___|  _ <  | |_| |  _|    / ___ \ | |
#  |_|    \___/  \_/\_/  |_____|_| \_\  \___/|_|     /_/   \_\___|
# Enter your Access Token:  DJyZc8lz4DJtpF_El_UAVFfDZpdgIRO4hU_a92x375A
# Error in getting accounts: {'error': {'errorCode': 'INVALID_REQUEST', 'description': 'Required oauth_token parameter is not present'}}
# Failed to get accounts.

# %%
# !pip install pyfiglet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests
import pandas as pd
import lightgbm as lgb
import pandas_ta as ta
import pyfiglet as pf

textArt = pf.figlet_format("F-14 >>>>>\n POWER OF AI")
print(textArt)

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# طلب إدخال Access Token من المستخدم
access_token = input("Enter your Access Token: ")

# استخدام Access Token للحصول على بيانات الـ "ticks"
def get_tick_data(access_token, symbol, count):
    url = f"https://api.spotware.com/connect/tradingaccounts/{symbol}/ticks?count={count}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data
        else:
            print("Error in getting tick data:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# جلب قائمة الحسابات
def get_accounts(access_token):
    url = "https://api.spotware.com/connect/tradingaccounts"  # رابط API الصحيح للحصول على الحسابات
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data['accounts']
        else:
            print("Error in getting accounts:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# تجميع كل 3 ticks إلى شمعة واحدة
def aggregate_ticks_to_candles(ticks_df):
    ticks_df['group'] = (ticks_df.index // 3)
    candles = ticks_df.groupby('group').agg({
        'price': ['first', 'max', 'min', 'last'],
        'volume': 'sum'
    })
    candles.columns = ['open', 'high', 'low', 'close', 'tick_volume']
    candles.dropna(inplace=True)
    return candles

# تنفيذ الوظائف
if __name__ == "__main__":
    if access_token:
        # جلب الحسابات المتاحة
        accounts = get_accounts(access_token)
        if accounts:
            print("Available accounts:")
            for account in accounts:
                print(f"Account ID: {account['id']}, Broker: {account['brokerName']}")

            # تحديد معرف الحساب الذي ترغب في التداول عليه
            selected_account_id = input("Enter the Account ID to trade on: ")
            symbol = "EURUSD"
            count = 300

            # الحصول على بيانات الـ "ticks"
            tick_data = get_tick_data(access_token, symbol, count)
            if tick_data:
                ticks_df = pd.DataFrame(tick_data['ticks'])
                candles_df = aggregate_ticks_to_candles(ticks_df)

                # حساب المؤشرات الفنية باستخدام pandas-ta
                candles_df['EMA_100'] = ta.ema(candles_df['close'], length=100)
                candles_df['EMA_50'] = ta.ema(candles_df['close'], length=50)
                candles_df['EMA_21'] = ta.ema(candles_df['close'], length=21)
                candles_df['EMA_13'] = ta.ema(candles_df['close'], length=13)
                candles_df['EMA_7'] = ta.ema(candles_df['close'], length=7)
                candles_df['RSI_10'] = ta.rsi(candles_df['close'], length=10)
                candles_df['ATR_10'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=10)
                candles_df['ATR_30'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=30)

                input_data = candles_df.iloc[-1][['open', 'high', 'low', 'close', 'tick_volume',
                                                  'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                                                  'RSI_10', 'ATR_10', 'ATR_30']]

                input_df = pd.DataFrame([input_data])
                features = ['open', 'high', 'low', 'close', 'tick_volume',
                            'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                            'RSI_10', 'ATR_10', 'ATR_30']
                input_df = input_df[features]

                # التنبؤ باستخدام النموذج
                prediction = model.predict(input_df)
                print(f"Prediction: {prediction[0]}")

                # تنفيذ أمر تداول بناءً على التنبؤ
                if prediction[0] > 0.5:  # مثال على شرط لتنفيذ أمر شراء
                    print("Placing a buy order...")
                    # هنا يمكنك إضافة الكود لتنفيذ الأمر باستخدام API الخاصة بـ Spotware
            else:
                print("Failed to get tick data.")
        else:
            print("Failed to get accounts.")
    else:
        print("Access Token is required.")
# Out:
#  _____     _ _  _    __________
# |  ___|   / | || |   \ \ \ \ \ \
# | |_ _____| | || |_   \ \ \ \ \ \
# |  _|_____| |__   _|  / / / / / /
# |_|       |_|  |_|   /_/_/_/_/_/
#
#   ____   _____        _______ ____     ___  _____      _    ___
#  |  _ \ / _ \ \      / / ____|  _ \   / _ \|  ___|    / \  |_ _|
#  | |_) | | | \ \ /\ / /|  _| | |_) | | | | | |_      / _ \  | |
#  |  __/| |_| |\ V  V / | |___|  _ <  | |_| |  _|    / ___ \ | |
#  |_|    \___/  \_/\_/  |_____|_| \_\  \___/|_|     /_/   \_\___|
# Enter your Access Token:  YeHZLXSmb1FMVl9AQN2yPDhkFvLiSci-niavN6pA72M
# Error in getting accounts: {'error': {'errorCode': 'INVALID_REQUEST', 'description': 'Required oauth_token parameter is not present'}}
# Failed to get accounts.

# %%
import requests
import pandas as pd
import lightgbm as lgb
import pandas_ta as ta

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# طلب إدخال OAuth Token من المستخدم
oauth_token = input("Enter your OAuth Token: ")

# استخدام OAuth Token للحصول على بيانات الـ "ticks"
def get_tick_data(oauth_token, symbol, count):
    url = f"https://api.spotware.com/connect/tradingaccounts/{symbol}/ticks?count={count}"
    headers = {
        "Authorization": f"Bearer {oauth_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data
        else:
            print("Error in getting tick data:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# جلب قائمة الحسابات
def get_accounts(oauth_token):
    url = "https://api.spotware.com/connect/tradingaccounts"  # رابط API الصحيح للحصول على الحسابات
    headers = {
        "Authorization": f"Bearer {oauth_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data['accounts']
        else:
            print("Error in getting accounts:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# تجميع كل 3 ticks إلى شمعة واحدة
def aggregate_ticks_to_candles(ticks_df):
    ticks_df['group'] = (ticks_df.index // 3)
    candles = ticks_df.groupby('group').agg({
        'price': ['first', 'max', 'min', 'last'],
        'volume': 'sum'
    })
    candles.columns = ['open', 'high', 'low', 'close', 'tick_volume']
    candles.dropna(inplace=True)
    return candles

# تنفيذ الوظائف
if __name__ == "__main__":
    if oauth_token:
        # جلب الحسابات المتاحة
        accounts = get_accounts(oauth_token)
        if accounts:
            print("Available accounts:")
            for account in accounts:
                print(f"Account ID: {account['id']}, Broker: {account['brokerName']}")

            # تحديد معرف الحساب الذي ترغب في التداول عليه
            selected_account_id = input("Enter the Account ID to trade on: ")
            symbol = "EURUSD"
            count = 300

            # الحصول على بيانات الـ "ticks"
            tick_data = get_tick_data(oauth_token, symbol, count)
            if tick_data:
                ticks_df = pd.DataFrame(tick_data['ticks'])
                candles_df = aggregate_ticks_to_candles(ticks_df)

                # حساب المؤشرات الفنية باستخدام pandas-ta
                candles_df['EMA_100'] = ta.ema(candles_df['close'], length=100)
                candles_df['EMA_50'] = ta.ema(candles_df['close'], length=50)
                candles_df['EMA_21'] = ta.ema(candles_df['close'], length=21)
                candles_df['EMA_13'] = ta.ema(candles_df['close'], length=13)
                candles_df['EMA_7'] = ta.ema(candles_df['close'], length=7)
                candles_df['RSI_10'] = ta.rsi(candles_df['close'], length=10)
                candles_df['ATR_10'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=10)
                candles_df['ATR_30'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=30)

                input_data = candles_df.iloc[-1][['open', 'high', 'low', 'close', 'tick_volume',
                                                  'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                                                  'RSI_10', 'ATR_10', 'ATR_30']]

                input_df = pd.DataFrame([input_data])
                features = ['open', 'high', 'low', 'close', 'tick_volume',
                            'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                            'RSI_10', 'ATR_10', 'ATR_30']
                input_df = input_df[features]

                # التنبؤ باستخدام النموذج
                prediction = model.predict(input_df)
                print(f"Prediction: {prediction[0]}")

                # تنفيذ أمر تداول بناءً على التنبؤ
                if prediction[0] > 0.5:  # مثال على شرط لتنفيذ أمر شراء
                    print("Placing a buy order...")
                    # هنا يمكنك إضافة الكود لتنفيذ الأمر باستخدام API الخاصة بـ Spotware
            else:
                print("Failed to get tick data.")
        else:
            print("Failed to get accounts.")
    else:
        print("OAuth Token is required.")
# Out:
# Enter your OAuth Token:  DJyZc8lz4DJtpF_El_UAVFfDZpdgIRO4hU_a92x375A
# Error in getting accounts: {'error': {'errorCode': 'INVALID_REQUEST', 'description': 'Required oauth_token parameter is not present'}}
# Failed to get accounts.

# %%
import requests
import pandas as pd
import lightgbm as lgb
import pandas_ta as ta

# تحميل النموذج المدرب
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# طلب إدخال CLIENT_ID و CLIENT_SECRET من المستخدم
CLIENT_ID = input("Enter your CLIENT_ID: ")
CLIENT_SECRET = input("Enter your CLIENT_SECRET: ")

# الحصول على Access Token
def get_access_token(client_id, client_secret):
    url = "https://connect.spotware.com/oauth2/token"
    payload = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret
    }
    
    response = requests.post(url, data=payload)
    
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data.get("access_token")
        else:
            print("Error in getting access token:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# استخدام Access Token للحصول على بيانات الـ "ticks"
def get_tick_data(access_token, symbol, count):
    url = f"https://api.spotware.com/connect/tradingaccounts/{symbol}/ticks?count={count}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data
        else:
            print("Error in getting tick data:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# جلب قائمة الحسابات
def get_accounts(access_token):
    url = "https://api.spotware.com/connect/tradingaccounts"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    response = requests.get(url, headers=headers)
    try:
        response_data = response.json()
        if response.status_code == 200:
            return response_data['accounts']
        else:
            print("Error in getting accounts:", response_data)
            return None
    except requests.exceptions.JSONDecodeError:
        print("Failed to decode JSON. Response text:", response.text)
        return None

# تجميع كل 3 ticks إلى شمعة واحدة
def aggregate_ticks_to_candles(ticks_df):
    ticks_df['group'] = (ticks_df.index // 3)
    candles = ticks_df.groupby('group').agg({
        'price': ['first', 'max', 'min', 'last'],
        'volume': 'sum'
    })
    candles.columns = ['open', 'high', 'low', 'close', 'tick_volume']
    candles.dropna(inplace=True)
    return candles

# تنفيذ الوظائف
if __name__ == "__main__":
    # الحصول على Access Token
    access_token = get_access_token(CLIENT_ID, CLIENT_SECRET)
    
    if access_token:
        # جلب الحسابات المتاحة
        accounts = get_accounts(access_token)
        if accounts:
            print("Available accounts:")
            for account in accounts:
                print(f"Account ID: {account['id']}, Broker: {account['brokerName']}")

            # تحديد معرف الحساب الذي ترغب في التداول عليه
            selected_account_id = input("Enter the Account ID to trade on: ")
            symbol = "EURUSD"
            count = 300

            # الحصول على بيانات الـ "ticks"
            tick_data = get_tick_data(access_token, symbol, count)
            if tick_data:
                ticks_df = pd.DataFrame(tick_data['ticks'])
                candles_df = aggregate_ticks_to_candles(ticks_df)

                # حساب المؤشرات الفنية باستخدام pandas-ta
                candles_df['EMA_100'] = ta.ema(candles_df['close'], length=100)
                candles_df['EMA_50'] = ta.ema(candles_df['close'], length=50)
                candles_df['EMA_21'] = ta.ema(candles_df['close'], length=21)
                candles_df['EMA_13'] = ta.ema(candles_df['close'], length=13)
                candles_df['EMA_7'] = ta.ema(candles_df['close'], length=7)
                candles_df['RSI_10'] = ta.rsi(candles_df['close'], length=10)
                candles_df['ATR_10'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=10)
                candles_df['ATR_30'] = ta.atr(candles_df['high'], candles_df['low'], candles_df['close'], length=30)

                input_data = candles_df.iloc[-1][['open', 'high', 'low', 'close', 'tick_volume',
                                                  'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                                                  'RSI_10', 'ATR_10', 'ATR_30']]

                input_df = pd.DataFrame([input_data])
                features = ['open', 'high', 'low', 'close', 'tick_volume',
                            'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                            'RSI_10', 'ATR_10', 'ATR_30']
                input_df = input_df[features]

                # التنبؤ باستخدام النموذج
                prediction = model.predict(input_df)
                print(f"Prediction: {prediction[0]}")

                # تنفيذ أمر تداول بناءً على التنبؤ
                if prediction[0] > 0.5:  # مثال على شرط لتنفيذ أمر شراء
                    print("Placing a buy order...")
                    # هنا يمكنك إضافة الكود لتنفيذ الأمر باستخدام API الخاصة بـ Spotware
            else:
                print("Failed to get tick data.")
        else:
            print("Failed to get accounts.")
    else:
        print("Failed to get access token.")
# Out:
# Enter your CLIENT_ID:  12063_H9AEW0UKNXCY9zkUMVZ6ikKRyRzkS4HflhEfTAe7M1GnPyRDrm
# Enter your CLIENT_SECRET:  XD25AP1bl0Ssmm8sKKXS3cxoTcws2SY4Li5k3wrxcpY3uOl5z7
# Failed to decode JSON. Response text: <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#
#         <title>Not Found</title>
#
#         <style>
# ...

# %%
import requests
import websocket
import json

# Credentials and URLs
client_id = '12063_H9AEW0UKNXCY9zkUMVZ6ikKRyRzkS4HflhEfTAe7M1GnPyRDrm'
client_secret = 'XD25AP1bl0Ssmm8sKKXS3cxoTcws2SY4Li5k3wrxcpY3uOl5z7'
account_id = '6054628'
access_token = 'DJyZc8lz4DJtpF_El_UAVFfDZpdgIRO4hU_a92x375A'  # Obtain this via OAuth2

# Base URLs
auth_url = "https://connect.spotware.com/apps/auth"
api_base_url = "https://api.spotware.com/v2"
ws_url = "wss://api.spotware.com/streaming/ws"

# OAuth2 Authentication to get access token
def get_access_token(client_id, client_secret):
    auth_response = requests.post(auth_url, data={
        'client_id': client_id,
        'client_secret': client_secret,
        'grant_type': 'client_credentials'
    })
    return auth_response.json()['access_token']

# WebSocket connection
def on_message(ws, message):
    print("Received message: ", message)

def on_error(ws, error):
    print("Error: ", error)

def on_close(ws):
    print("WebSocket closed")

def on_open(ws):
    print("WebSocket connection established")
    # Example: subscribing to account and price data
    subscribe_message = {
        "command": "subscribe",
        "streaming_type": "price",
        "symbol": "EURUSD",
        "account_id": account_id
    }
    ws.send(json.dumps(subscribe_message))

# Main function to initiate WebSocket connection
def start_websocket():
    ws = websocket.WebSocketApp(ws_url,
                                on_open=on_open,
                                on_message=on_message,
                                on_error=on_error,
                                on_close=on_close)
    ws.run_forever()

# Example: Placing a market order (HTTP request)
def place_order():
    headers = {"Authorization": f"Bearer {access_token}"}
    order_payload = {
        "accountId": account_id,
        "symbolId": 1,  # EURUSD for example
        "orderType": "Market",
        "tradeSide": "BUY",
        "volume": 100000,
        "clientTag": "order001"
    }
    response = requests.post(f"{api_base_url}/accounts/{account_id}/orders", 
                             headers=headers, 
                             json=order_payload)
    print(response.json())

# Usage
access_token = get_access_token(client_id, client_secret)
start_websocket()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\ProgramData\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
import requests
import websocket
import json

# Credentials and URLs
client_id = '12063_H9AEW0UKNXCY9zkUMVZ6ikKRyRzkS4HflhEfTAe7M1GnPyRDrm'
client_secret = 'XD25AP1bl0Ssmm8sKKXS3cxoTcws2SY4Li5k3wrxcpY3uOl5z7'
account_id = '6054628'
auth_url = "https://connect.spotware.com/apps/auth"  # Verify the correct OAuth2 endpoint
api_base_url = "https://api.spotware.com/v2"
ws_url = "wss://api.spotware.com/streaming/ws"


# OAuth2 Authentication to get access token
def get_access_token(client_id, client_secret):
    auth_response = requests.post(auth_url, data={
        'client_id': client_id,
        'client_secret': client_secret,
        'grant_type': 'client_credentials'  # Adjust this if a different grant type is needed
    })
    
    print("Status Code:", auth_response.status_code)  # Check if request was successful (200)
    print("Response Content:", auth_response.text)  # Print raw response content to debug
    
    # Try to parse the JSON response
    try:
        auth_data = auth_response.json()  # Attempt to parse response
        if 'access_token' in auth_data:
            return auth_data['access_token']
        else:
            print("Access token not found in the response:", auth_data)
            return None
    except ValueError as e:  # If JSON decoding fails
        print("Error parsing JSON response:", e)
        return None


# WebSocket Handlers
def on_message(ws, message):
    print("Received message: ", message)


def on_error(ws, error):
    print("WebSocket Error: ", error)


def on_close(ws):
    print("WebSocket closed")


def on_open(ws):
    print("WebSocket connection established")
    # Example: subscribing to account and price data
    subscribe_message = {
        "command": "subscribe",
        "streaming_type": "price",
        "symbol": "EURUSD",  # Modify this symbol if needed
        "account_id": account_id
    }
    ws.send(json.dumps(subscribe_message))


# WebSocket connection function
def start_websocket(access_token):
    headers = {"Authorization": f"Bearer {access_token}"}
    ws = websocket.WebSocketApp(ws_url,
                                on_open=on_open,
                                on_message=on_message,
                                on_error=on_error,
                                on_close=on_close,
                                header=headers)
    ws.run_forever()


# Example: Placing a market order (HTTP request)
def place_order(access_token):
    headers = {"Authorization": f"Bearer {access_token}"}
    order_payload = {
        "accountId": account_id,
        "symbolId": 1,  # EURUSD, change to appropriate symbolId if necessary
        "orderType": "Market",
        "tradeSide": "BUY",
        "volume": 100000,  # Volume in terms of lots, adjust this as per your needs
        "clientTag": "order001"
    }
    response = requests.post(f"{api_base_url}/accounts/{account_id}/orders", 
                             headers=headers, 
                             json=order_payload)
    
    print("Order Placement Response Status Code:", response.status_code)
    print("Order Placement Response Content:", response.text)
    if response.status_code == 200:
        print("Order placed successfully:", response.json())
    else:
        print("Failed to place order:", response.text)


# Main Execution
access_token = get_access_token(client_id, client_secret)

if access_token:
    print("Access Token Obtained:", access_token)
    # Start the WebSocket to get real-time data
    start_websocket(access_token)

    # Optionally, place an order
    place_order(access_token)
else:
    print("Failed to obtain access token.")
# Out:
# Status Code: 405
# Response Content: <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8" />
#     <meta name="robots" content="noindex,nofollow,noarchive" />
#     <title>An Error Occurred: Method Not Allowed</title>
#     <link rel="icon" href="data:image/svg+xml,<svg xmlns=%22http://www.w3.org/2000/svg%22 viewBox=%220 0 128 128%22><text y=%221.2em%22 font-size=%2296%22>❌</text></svg>">
#     <style>body { background-color: #fff; color: #222; font: 16px/1.5 -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial, sans-serif; margin: 0; }
# .container { margin: 30px; max-width: 600px; }
# h1 { color: #dc3545; font-size: 24px; }
# h2 { font-size: 18px; }</style>
# </head>
# <body>
# <div class="container">
#     <h1>Oops! An Error Occurred</h1>
#     <h2>The server returned a "405 Method Not Allowed".</h2>
#
#     <p>
#         Something is broken. Please let us know what you were doing when this error occurred.
# ...

# %%
import pandas as pd
import lightgbm as lgb
import talib as ta
from ctrader_open_api import Client, Protobuf, TcpProtocol, EndPoints
from ctrader_open_api.messages.OpenApiCommonMessages_pb2 import *
from ctrader_open_api.messages.OpenApiMessages_pb2 import *
from twisted.internet import reactor

# نموذج الاتصال بـ cTrader
def onError(failure): 
    print("# Message Error: ", failure)

def connected(client): 
    print("# Connected")
    request = ProtoOAApplicationAuthReq()
    request.clientId = "12063_H9AEW0UKNXCY9zkUMVZ6ikKRyRzkS4HflhEfTAe7M1GnPyRDrm"
    request.clientSecret = "XD25AP1bl0Ssmm8sKKXS3cxoTcws2SY4Li5k3wrxcpY3uOl5z7"
    deferred = client.send(request)
    deferred.addErrback(onError)

def disconnected(client, reason):
    print("\n# Disconnected: ", reason)

def onMessageReceived(client, message): 
    print("# Message received: \n", Protobuf.extract(message))

# إعداد الاتصال بـ cTrader
host = EndPoints.PROTOBUF_LIVE_HOST
client = Client(host, EndPoints.PROTOBUF_PORT, TcpProtocol)
client.setConnectedCallback(connected)
client.setDisconnectedCallback(disconnected)
client.setMessageReceivedCallback(onMessageReceived)
client.startService()

# تشغيل Twisted reactor
reactor.run()

# نموذج LightGBM المحمل
model = lgb.Booster(model_file=r'C:\Users\Access\Downloads\lightgbm_model.txt')

# قائمة لتخزين التِك
tick_data = []

# تخزين الشموع في DataFrame
candles = pd.DataFrame(columns=['Open', 'High', 'Low', 'Close', 'Volume'])

def process_tick(tick):
    global tick_data, candles
    
    # إضافة التِك إلى القائمة
    tick_data.append(tick)
    
    # إذا تم تجميع 3 تِك
    if len(tick_data) == 3:
        # تكوين شمعة
        open_price = tick_data[0]['price']
        high_price = max(t['price'] for t in tick_data)
        low_price = min(t['price'] for t in tick_data)
        close_price = tick_data[-1]['price']
        volume = sum(t['volume'] for t in tick_data)

        # إضافة الشمعة إلى DataFrame
        new_candle = pd.DataFrame([{
            'Open': open_price,
            'High': high_price,
            'Low': low_price,
            'Close': close_price,
            'Volume': volume
        }])
        
        candles = pd.concat([candles, new_candle], ignore_index=True)
        
        # تفريغ التِك بعد تكوين الشمعة
        tick_data = []
        
        # إذا كان لدينا 100 شمعة على الأقل، احسب المؤشرات الفنية
        if len(candles) >= 100:
            # حساب المؤشرات الفنية باستخدام TA-Lib
            candles['EMA_100'] = ta.EMA(candles['Close'], timeperiod=100)
            candles['EMA_50'] = ta.EMA(candles['Close'], timeperiod=50)
            candles['EMA_21'] = ta.EMA(candles['Close'], timeperiod=21)
            candles['EMA_13'] = ta.EMA(candles['Close'], timeperiod=13)
            candles['EMA_7'] = ta.EMA(candles['Close'], timeperiod=7)
            candles['RSI_10'] = ta.RSI(candles['Close'], timeperiod=10)
            candles['ATR_10'] = ta.ATR(candles['High'], candles['Low'], candles['Close'], timeperiod=10)
            candles['ATR_30'] = ta.ATR(candles['High'], candles['Low'], candles['Close'], timeperiod=30)
            
            # الحصول على آخر 100 شمعة لاستخدامها في التنبؤ
            input_data = candles[-100:]
            
            # التأكد من ترتيب الأعمدة
            features = ['Open', 'High', 'Low', 'Close', 'Volume',
                        'EMA_100', 'EMA_50', 'EMA_21', 'EMA_13', 'EMA_7',
                        'RSI_10', 'ATR_10', 'ATR_30']
            input_data = input_data[features]

            # التنبؤ باستخدام النموذج
            prediction = model.predict(input_data)
            
            # عرض النتيجة
            print(f'التنبؤ: {prediction[-1]}')  # عرض النتيجة الأخيرة

# الكود أعلاه يشرح كيفية تجميع 3 تِك في شمعة واستخدامها للتنبؤ

# ملاحظة: عليك إضافة كود لاستقبال بيانات التِك من cTrader 
# وعندما تحصل على تِك، قم بتمريرها إلى دالة process_tick

# مثال على تِك (يجب تغييره ليعمل مع بيانات التِك الحقيقية)
example_tick = {'price': 1.12345, 'volume': 1000}
process_tick(example_tick)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Read the image
image = mpimg.imread(r'C:\Users\Access\Downloads\SolarFull_SeanDoran_2880FullwidthLede-768x432.jpg')

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.show()

# %%
import MetaTrader5 as mt5
from datetime import datetime, timedelta
import time
import pandas as pd
import pytz

# رمز العملة
symbol = "EURUSD"

# محاولة الاتصال بـ MetaTrader 5 بشكل مستمر حتى النجاح
while not mt5.initialize():
    print("Connection failed. Retrying...")
    time.sleep(2)  # الانتظار لبضع ثوانٍ قبل المحاولة مرة أخرى

print("Connected to MetaTrader 5 successfully.")


# الوقت الحالي بتوقيت GMT+3
now = datetime.now()


# جلب أحدث 300 تكة بدءًا من الوقت الحالي
ticks = mt5.copy_ticks_range(symbol, now - timedelta(minutes=5), now , mt5.COPY_TICKS_INFO)

# تحويل البيانات إلى DataFrame
df = pd.DataFrame(ticks, columns=['time', 'bid', 'ask', 'last', 'volume', 'time_msc', 'flags', 'volume_real'])

# تحويل التوقيت من Unix إلى datetime
df['time'] = pd.to_datetime(df['time'], unit='s')

# عرض البيانات
print(df)

# تجميع كل 3 شمعات في شمعة واحدة
grouped = df.groupby(df.index // 3).agg({
    'bid': ['first', 'max', 'min', 'last']
})

# تبسيط أسماء الأعمدة
grouped.columns = ['open', 'high', 'low', 'close']

# عرض النتائج
print(grouped)

# إنهاء الاتصال بـ MetaTrader 5
mt5.shutdown()
# Out:
# Connected to MetaTrader 5 successfully.
#                    time      bid      ask  last  volume       time_msc  flags  \
# 0   2024-10-30 00:07:26  1.08126  1.08160   0.0       0  1730246846781      4
# 1   2024-10-30 00:07:28  1.08126  1.08162   0.0       0  1730246848379      4
# 2   2024-10-30 00:07:31  1.08126  1.08163   0.0       0  1730246851641      4
# 3   2024-10-30 00:07:31  1.08126  1.08161   0.0       0  1730246851806      4
# 4   2024-10-30 00:07:34  1.08126  1.08163   0.0       0  1730246854552      4
# ..                  ...      ...      ...   ...     ...            ...    ...
# 133 2024-10-30 00:12:03  1.08148  1.08169   0.0       0  1730247123805      4
# 134 2024-10-30 00:12:05  1.08147  1.08169   0.0       0  1730247125907      2
# 135 2024-10-30 00:12:08  1.08148  1.08169   0.0       0  1730247128866      2
# 136 2024-10-30 00:12:09  1.08145  1.08169   0.0       0  1730247129693      2
# ...
