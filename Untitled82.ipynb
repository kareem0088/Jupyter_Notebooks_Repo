# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models

# =========================
# === User Variables ===
# =========================
# Place your directories or links below:
NORMAL_DATA_DIR = r"C:\Users\Access\Documents\crack_wall"  # e.g. '/mnt/data/normal_walls/'
CRACK_DATA_DIR = r"C:\Users\Access\Documents\non_crack_wall"     # e.g. '/mnt/data/cracked_walls/'

# Image parameters
IMG_HEIGHT = 128
IMG_WIDTH = 128
BATCH_SIZE = 32

# =========================
# === Data Loading ===
# =========================
# Load only normal images for training
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    NORMAL_DATA_DIR,
    labels=None,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=True
)

# Load both normal and cracked images for testing
test_normal_ds = tf.keras.preprocessing.image_dataset_from_directory(
    NORMAL_DATA_DIR,
    labels=None,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_crack_ds = tf.keras.preprocessing.image_dataset_from_directory(
    CRACK_DATA_DIR,
    labels=None,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=False
)

# Normalize pixel values to [0,1]
normalization_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x: normalization_layer(x))
test_normal_ds = test_normal_ds.map(lambda x: normalization_layer(x))
test_crack_ds = test_crack_ds.map(lambda x: normalization_layer(x))

# =========================
# === Build Autoencoder ===
# =========================
input_img = layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
# Encoder
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2,2), padding='same')(x)
x = layers.Conv2D(16, (3,3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2,2), padding='same')(x)

# Bottleneck
x = layers.Conv2D(8, (3,3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2,2), padding='same')(x)

# Decoder
x = layers.Conv2DTranspose(8, (3,3), strides=2, activation='relu', padding='same')(x)
x = layers.Conv2DTranspose(16, (3,3), strides=2, activation='relu', padding='same')(x)
x = layers.Conv2DTranspose(32, (3,3), strides=2, activation='relu', padding='same')(x)
decoded = layers.Conv2D(3, (3,3), activation='sigmoid', padding='same')(x)

autoencoder = models.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()

# =========================
# === Training ===
# =========================
epochs = 30
history = autoencoder.fit(
    train_ds,
    epochs=epochs,
    validation_data=test_normal_ds
)

# =========================
# === Compute Threshold ===
# =========================
# Calculate reconstruction error on normal test set
recons_errors = []
for batch in test_normal_ds:
    reconstructions = autoencoder.predict(batch)
    mse = np.mean(np.power(batch - reconstructions, 2), axis=(1,2,3))
    recons_errors.extend(mse)

threshold = np.mean(recons_errors) + 3*np.std(recons_errors)
print(f"Anomaly detection threshold: {threshold:.4f}")

# =========================
# === Evaluation ===
# =========================
def detect_anomalies(dataset, label):
    results = []
    for batch in dataset:
        reconstructions = autoencoder.predict(batch)
        mse = np.mean(np.power(batch - reconstructions, 2), axis=(1,2,3))
        preds = mse > threshold
        for m, p in zip(mse, preds):
            results.append((m, p, label))
    return results

results_normal = detect_anomalies(test_normal_ds, label=0)  # 0 = normal
results_crack = detect_anomalies(test_crack_ds, label=1)  # 1 = crack/damp

# Combine and show summary
all_results = results_normal + results_crack
all_results = np.array(all_results, dtype=object)

# Print a small sample of detections
print("Sample results (mse, is_anomaly, true_label):")
print(all_results[:10])

# =========================
# === Visualize some examples ===
# =========================
def plot_reconstruction(dataset, n=3):
    for batch in dataset.take(1):
        reconstructions = autoencoder.predict(batch)
        for i in range(n):
            plt.figure(figsize=(4,2))
            # Original
            plt.subplot(1,2,1)
            plt.title('Original')
            plt.imshow(batch[i].numpy())
            plt.axis('off')
            # Reconstructed
            plt.subplot(1,2,2)
            plt.title('Reconstructed')
            plt.imshow(reconstructions[i])
            plt.axis('off')
            plt.show()

# Show examples
plot_reconstruction(test_crack_ds)
plot_reconstruction(test_normal_ds)
# Out:
# Found 596 files.
# Found 596 files.
# Found 509 files.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models

# =========================
# === User Variables ===
# =========================
# Place your directories or links below:
NORMAL_DATA_DIR = r"C:\Users\Access\Documents\crack_wall"  # e.g. '/mnt/data/normal_walls/'
CRACK_DATA_DIR = r"C:\Users\Access\Documents\non_crack_wall"     # e.g. '/mnt/data/cracked_walls/'

# Image parameters
IMG_HEIGHT = 128
IMG_WIDTH = 128
BATCH_SIZE = 32

# =========================
# === Data Loading ===
# =========================
# Load only normal images for training
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    NORMAL_DATA_DIR,
    labels=None,
    label_mode=None,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=True
)

# Load normal images for validation and testing
test_normal_ds = tf.keras.preprocessing.image_dataset_from_directory(
    NORMAL_DATA_DIR,
    labels=None,
    label_mode=None,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=False
)

# Load cracked images for testing only
test_crack_ds = tf.keras.preprocessing.image_dataset_from_directory(
    CRACK_DATA_DIR,
    labels=None,
    label_mode=None,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=False
)

# Normalize pixel values to [0,1]
normalization_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x: normalization_layer(x))
test_normal_ds = test_normal_ds.map(lambda x: normalization_layer(x))
test_crack_ds = test_crack_ds.map(lambda x: normalization_layer(x))

# Prepare datasets for autoencoder (input, target) pairs
autoencoder_train = train_ds.map(lambda x: (x, x))
autoencoder_val = test_normal_ds.map(lambda x: (x, x))

# =========================
# === Build Autoencoder ===
# =========================
input_img = layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
# Encoder
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2,2), padding='same')(x)
x = layers.Conv2D(16, (3,3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2,2), padding='same')(x)

# Bottleneck
x = layers.Conv2D(8, (3,3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2,2), padding='same')(x)

# Decoder
x = layers.Conv2DTranspose(8, (3,3), strides=2, activation='relu', padding='same')(x)
x = layers.Conv2DTranspose(16, (3,3), strides=2, activation='relu', padding='same')(x)
x = layers.Conv2DTranspose(32, (3,3), strides=2, activation='relu', padding='same')(x)
decoded = layers.Conv2D(3, (3,3), activation='sigmoid', padding='same')(x)

autoencoder = models.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()

# =========================
# === Training ===
# =========================
epochs = 30
history = autoencoder.fit(
    autoencoder_train,
    epochs=epochs,
    validation_data=autoencoder_val
)

# =========================
# === Compute Threshold ===
# =========================
# Calculate reconstruction error on normal test set
recons_errors = []
for batch in test_normal_ds:
    reconstructions = autoencoder.predict(batch)
    mse = np.mean(np.power(batch - reconstructions, 2), axis=(1,2,3))
    recons_errors.extend(mse)

threshold = np.mean(recons_errors) + 3 * np.std(recons_errors)
print(f"Anomaly detection threshold: {threshold:.4f}")

# =========================
# === Evaluation ===
# =========================
def detect_anomalies(dataset, label):
    results = []
    for batch in dataset:
        reconstructions = autoencoder.predict(batch)
        mse = np.mean(np.power(batch - reconstructions, 2), axis=(1,2,3))
        preds = mse > threshold
        for m, p in zip(mse, preds):
            results.append((m, p, label))
    return results

results_normal = detect_anomalies(test_normal_ds, label=0)  # 0 = normal
results_crack = detect_anomalies(test_crack_ds, label=1)  # 1 = crack/damp

# Combine and show summary
all_results = np.array(results_normal + results_crack, dtype=object)
print("Sample results (mse, is_anomaly, true_label):")
print(all_results[:10])

# =========================
# === Visualize some examples ===
# =========================
def plot_reconstruction(dataset, n=3):
    for batch in dataset.take(1):
        reconstructions = autoencoder.predict(batch)
        for i in range(n):
            plt.figure(figsize=(4,2))
            # Original
            plt.subplot(1,2,1)
            plt.title('Original')
            plt.imshow(batch[i].numpy())
            plt.axis('off')
            # Reconstructed
            plt.subplot(1,2,2)
            plt.title('Reconstructed')
            plt.imshow(reconstructions[i])
            plt.axis('off')
            plt.show()

# Show examples
plot_reconstruction(test_crack_ds)
plot_reconstruction(test_normal_ds)
# Out:
# Found 596 files.
# Found 596 files.
# Found 509 files.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 64, 64, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report, confusion_matrix

# =========================
# === User Variables ===
# =========================
# Place your directories or links below:
NORMAL_DATA_DIR = r"C:\Users\Access\Documents\crack_wall"  # e.g. '/mnt/data/normal_walls/'
CRACK_DATA_DIR = r"C:\Users\Access\Documents\non_crack_wall"     # e.g. '/mnt/data/cracked_walls/'

# Image parameters
IMG_HEIGHT = 128
IMG_WIDTH = 128
BATCH_SIZE = 32

# =========================
# === Data Loading ===
# =========================
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    NORMAL_DATA_DIR,
    labels=None,
    label_mode=None,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_normal_ds = tf.keras.preprocessing.image_dataset_from_directory(
    NORMAL_DATA_DIR,
    labels=None,
    label_mode=None,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_crack_ds = tf.keras.preprocessing.image_dataset_from_directory(
    CRACK_DATA_DIR,
    labels=None,
    label_mode=None,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=False
)

# Normalize pixel values to [0,1]
normalization_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x: normalization_layer(x))
test_normal_ds = test_normal_ds.map(lambda x: normalization_layer(x))
test_crack_ds = test_crack_ds.map(lambda x: normalization_layer(x))

# Prepare datasets for autoencoder (input, target) pairs
autoencoder_train = train_ds.map(lambda x: (x, x))
autoencoder_val = test_normal_ds.map(lambda x: (x, x))

# =========================
# === Build Autoencoder ===
# =========================
input_img = layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
# Encoder
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2,2), padding='same')(x)
x = layers.Conv2D(16, (3,3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2,2), padding='same')(x)
# Bottleneck
x = layers.Conv2D(8, (3,3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2,2), padding='same')(x)
# Decoder
x = layers.Conv2DTranspose(8, (3,3), strides=2, activation='relu', padding='same')(x)
x = layers.Conv2DTranspose(16, (3,3), strides=2, activation='relu', padding='same')(x)
x = layers.Conv2DTranspose(32, (3,3), strides=2, activation='relu', padding='same')(x)
decoded = layers.Conv2D(3, (3,3), activation='sigmoid', padding='same')(x)

autoencoder = models.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()

# =========================
# === Training ===
# =========================
epochs = 30
history = autoencoder.fit(
    autoencoder_train,
    epochs=epochs,
    validation_data=autoencoder_val
)

# =========================
# === Compute Threshold ===
# =========================
recons_errors = []
for batch in test_normal_ds:
    reconstructions = autoencoder.predict(batch)
    mse = np.mean(np.power(batch - reconstructions, 2), axis=(1,2,3))
    recons_errors.extend(mse)
threshold = np.mean(recons_errors) + 3 * np.std(recons_errors)
print(f"Anomaly detection threshold: {threshold:.4f}")

# =========================
# === Evaluation ===
# =========================
def detect_anomalies(dataset, label):
    results = []
    for batch in dataset:
        reconstructions = autoencoder.predict(batch)
        mse = np.mean(np.power(batch - reconstructions, 2), axis=(1,2,3))
        preds = mse > threshold
        for m, p in zip(mse, preds):
            results.append((m, int(p), label))
    return results

results_normal = detect_anomalies(test_normal_ds, label=0)
results_crack = detect_anomalies(test_crack_ds, label=1)
all_results = np.array(results_normal + results_crack, dtype=int)

# =========================
# === Print Reports ===
# =========================
y_true = all_results[:,2]
y_pred = all_results[:,1]
print("\n=== Classification Report ===")
print(classification_report(y_true, y_pred, target_names=['normal','anomaly']))
print("\n=== Confusion Matrix ===")
print(confusion_matrix(y_true, y_pred))

# =========================
# === Visualize Examples ===
# =========================
def plot_reconstruction(dataset, n=3):
    for batch in dataset.take(1):
        reconstructions = autoencoder.predict(batch)
        for i in range(n):
            plt.figure(figsize=(4,2))
            plt.subplot(1,2,1)
            plt.title('Original')
            plt.imshow(batch[i].numpy())
            plt.axis('off')
            plt.subplot(1,2,2)
            plt.title('Reconstructed')
            plt.imshow(reconstructions[i])
            plt.axis('off')
            plt.show()

plot_reconstruction(test_crack_ds)
plot_reconstruction(test_normal_ds)
# Out:
# Found 596 files.
# Found 596 files.
# Found 509 files.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
