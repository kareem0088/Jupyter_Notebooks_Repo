# %%
import pandas as pd
import numpy as np
from binance.client import Client
from datetime import datetime, timedelta, timezone
from tqdm import tqdm
import time

# اتصال بباينانس
client = Client("", "")  # مش محتاج API Keys للبيانات العامة
symbol = "BTCUSDT"
interval = Client.KLINE_INTERVAL_1MINUTE
end = datetime.now(timezone.utc)
start = end - timedelta(days=1)

# تحميل الشموع التاريخية (OHLCV)
klines = client.get_historical_klines(
    symbol,
    interval,
    start.strftime("%Y-%m-%d %H:%M:%S"),
    end.strftime("%Y-%m-%d %H:%M:%S")
)

# DataFrame للشموع
df = pd.DataFrame(klines, columns=[
    "open_time","open","high","low","close","volume",
    "close_time","quote_av","trades","taker_buy_base_av","taker_buy_quote_av","ignore"
])

# تحويل الأنواع
float_cols = ["open","high","low","close","volume","taker_buy_base_av","taker_buy_quote_av","quote_av"]
df[float_cols] = df[float_cols].astype(float)
df["trades"] = df["trades"].astype(int)
df["time"] = pd.to_datetime(df["open_time"], unit="ms")

print(f"Loaded {len(df)} candles")

# ===========================================================
# جلب جميع الصفقات لليوم كامل مرة واحدة
# ===========================================================

def get_all_trades_for_period(client, symbol, start_time, end_time):
    """جلب جميع الصفقات لفترة زمنية محددة"""
    all_trades = []
    current_start = start_time
    
    print("Fetching all trades for the day...")
    
    while current_start < end_time:
        try:
            # طلب الصفقات (الحد الأقصى 1000 صفقة لكل طلب)
            trades = client.get_aggregate_trades(
                symbol=symbol, 
                startTime=current_start, 
                endTime=end_time,
                limit=1000
            )
            
            if not trades:
                break
                
            all_trades.extend(trades)
            
            # تحديث وقت البداية للطلب التالي
            current_start = trades[-1]['T'] + 1  # T هو وقت الصفقة
            
            print(f"Fetched {len(trades)} trades, total: {len(all_trades)}")
            
            # تجنب تجاوز حدود الAPI
            time.sleep(0.1)
            
        except Exception as e:
            print(f"Error fetching trades: {e}")
            break
    
    return all_trades

# جلب جميع الصفقات لليوم
start_timestamp = int(start.timestamp() * 1000)
end_timestamp = int(end.timestamp() * 1000)

all_trades = get_all_trades_for_period(client, symbol, start_timestamp, end_timestamp)
print(f"Total trades fetched: {len(all_trades)}")

# تحويل الصفقات إلى DataFrame
trades_df = pd.DataFrame(all_trades)
trades_df['time'] = pd.to_datetime(trades_df['T'], unit='ms')  # T هو timestamp
trades_df['quantity'] = trades_df['q'].astype(float)
trades_df['is_buyer_maker'] = trades_df['m']  # True = البائع هو taker, False = المشتري هو taker

# ===========================================================
# توزيع الصفقات على الشموع
# ===========================================================

def assign_trades_to_candles(df, trades_df):
    """توزيع الصفقات على الشموع المناسبة"""
    
    buy_trades_list = []
    sell_trades_list = []
    buy_volume_list = []
    sell_volume_list = []
    
    print("Assigning trades to candles...")
    
    for i, row in tqdm(df.iterrows(), total=len(df), desc="Processing candles"):
        start_t = pd.to_datetime(row["open_time"], unit="ms")
        end_t = pd.to_datetime(row["close_time"], unit="ms")
        
        # فلترة الصفقات التي تقع في نطاق هذه الشمعة
        candle_trades = trades_df[
            (trades_df['time'] >= start_t) & 
            (trades_df['time'] <= end_t)
        ]
        
        if len(candle_trades) > 0:
            # تصنيف الصفقات
            buy_trades = candle_trades[~candle_trades['is_buyer_maker']]  # المشتري هو taker
            sell_trades = candle_trades[candle_trades['is_buyer_maker']]   # البائع هو taker
            
            buy_count = len(buy_trades)
            sell_count = len(sell_trades)
            buy_vol = buy_trades['quantity'].sum() if buy_count > 0 else 0
            sell_vol = sell_trades['quantity'].sum() if sell_count > 0 else 0
        else:
            buy_count = sell_count = 0
            buy_vol = sell_vol = 0
        
        buy_trades_list.append(buy_count)
        sell_trades_list.append(sell_count)
        buy_volume_list.append(buy_vol)
        sell_volume_list.append(sell_vol)
    
    return buy_trades_list, sell_trades_list, buy_volume_list, sell_volume_list

# تطبيق التوزيع
buy_trades_list, sell_trades_list, buy_volume_list, sell_volume_list = assign_trades_to_candles(df, trades_df)

# إضافة النتائج للـ DataFrame
df["buy_trades"] = buy_trades_list
df["sell_trades"] = sell_trades_list
df["buy_volume"] = buy_volume_list
df["sell_volume"] = sell_volume_list

# المشتقات
df["delta_volume"] = df["buy_volume"] - df["sell_volume"]
df["avg_trade_size"] = df["volume"] / df["trades"]
df["imbalance"] = df["buy_volume"] / df["volume"]
df["vwap"] = df["quote_av"] / df["volume"]
df["volatility"] = df["high"] - df["low"]

# ترتيب الأعمدة
cols = ["time","open","high","low","close","volume","trades",
        "buy_volume","sell_volume","buy_trades","sell_trades",
        "delta_volume","avg_trade_size","imbalance","vwap","volatility"]
df = df[cols]

# عرض النتائج
print("\nFinal DataFrame:")
print(df.head(10))

# إحصائيات سريعة للتأكد من صحة البيانات
print(f"\nStatistics:")
print(f"Total candles: {len(df)}")
print(f"Total trades processed: {len(all_trades)}")
print(f"Total buy volume: {df['buy_volume'].sum():.2f}")
print(f"Total sell volume: {df['sell_volume'].sum():.2f}")
print(f"Volume difference: {(df['buy_volume'].sum() + df['sell_volume'].sum()) - df['volume'].sum():.2f}")
# Out:
# C:\Users\Access\AppData\Local\Temp\ipykernel_20348\3999041499.py:16: DeprecationWarning: Parsing dates involving a day of month without a year specified is ambiguious
# and fails to parse leap day. The default behavior will change in Python 3.15
# to either always raise an exception or to use a different default year (TBD).
# To avoid trouble, add a specific year to the input & format.
# See https://github.com/python/cpython/issues/70647.
#   klines = client.get_historical_klines(
# Loaded 1440 candles
# Fetching all trades for the day...
# Fetched 1000 trades, total: 1000
# Fetched 1000 trades, total: 2000
# Fetched 1000 trades, total: 3000
# Fetched 1000 trades, total: 4000
# Fetched 1000 trades, total: 5000
# Fetched 1000 trades, total: 6000
# Fetched 1000 trades, total: 7000
# Fetched 1000 trades, total: 8000
# Fetched 1000 trades, total: 9000
# Fetched 1000 trades, total: 10000
# Fetched 1000 trades, total: 11000
# Fetched 1000 trades, total: 12000
# Fetched 1000 trades, total: 13000
# Fetched 1000 trades, total: 14000
# Fetched 1000 trades, total: 15000
# Fetched 1000 trades, total: 16000
# Fetched 1000 trades, total: 17000
# Fetched 1000 trades, total: 18000
# Fetched 1000 trades, total: 19000
# Fetched 1000 trades, total: 20000
# Fetched 1000 trades, total: 21000
# Fetched 1000 trades, total: 22000
# Fetched 1000 trades, total: 23000
# Fetched 1000 trades, total: 24000
# Fetched 1000 trades, total: 25000
# Fetched 1000 trades, total: 26000
# Fetched 1000 trades, total: 27000
# Fetched 1000 trades, total: 28000
# Fetched 1000 trades, total: 29000
# Fetched 1000 trades, total: 30000
# Fetched 1000 trades, total: 31000
# Fetched 1000 trades, total: 32000
# Fetched 1000 trades, total: 33000
# Fetched 1000 trades, total: 34000
# Fetched 1000 trades, total: 35000
# Fetched 1000 trades, total: 36000
# Fetched 1000 trades, total: 37000
# Fetched 1000 trades, total: 38000
# Fetched 1000 trades, total: 39000
# Fetched 1000 trades, total: 40000
# Fetched 1000 trades, total: 41000
# Fetched 1000 trades, total: 42000
# Fetched 1000 trades, total: 43000
# Fetched 1000 trades, total: 44000
# Fetched 1000 trades, total: 45000
# Fetched 1000 trades, total: 46000
# Fetched 1000 trades, total: 47000
# Fetched 1000 trades, total: 48000
# Fetched 1000 trades, total: 49000
# Fetched 1000 trades, total: 50000
# Fetched 1000 trades, total: 51000
# Fetched 1000 trades, total: 52000
# Fetched 1000 trades, total: 53000
# Fetched 1000 trades, total: 54000
# Fetched 1000 trades, total: 55000
# Fetched 1000 trades, total: 56000
# Fetched 1000 trades, total: 57000
# Fetched 1000 trades, total: 58000
# Fetched 1000 trades, total: 59000
# Fetched 1000 trades, total: 60000
# Fetched 1000 trades, total: 61000
# Fetched 1000 trades, total: 62000
# Fetched 1000 trades, total: 63000
# Fetched 1000 trades, total: 64000
# Fetched 1000 trades, total: 65000
# Fetched 1000 trades, total: 66000
# Fetched 1000 trades, total: 67000
# Fetched 1000 trades, total: 68000
# Fetched 1000 trades, total: 69000
# Fetched 1000 trades, total: 70000
# Fetched 1000 trades, total: 71000
# Fetched 1000 trades, total: 72000
# Fetched 1000 trades, total: 73000
# Fetched 1000 trades, total: 74000
# Fetched 1000 trades, total: 75000
# Fetched 1000 trades, total: 76000
# Fetched 1000 trades, total: 77000
# Fetched 1000 trades, total: 78000
# Fetched 1000 trades, total: 79000
# Fetched 1000 trades, total: 80000
# Fetched 1000 trades, total: 81000
# Fetched 1000 trades, total: 82000
# Fetched 1000 trades, total: 83000
# Fetched 1000 trades, total: 84000
# Fetched 1000 trades, total: 85000
# Fetched 1000 trades, total: 86000
# Fetched 1000 trades, total: 87000
# Fetched 1000 trades, total: 88000
# Fetched 1000 trades, total: 89000
# Fetched 1000 trades, total: 90000
# Fetched 1000 trades, total: 91000
# Fetched 1000 trades, total: 92000
# Fetched 1000 trades, total: 93000
# Fetched 1000 trades, total: 94000
# Fetched 1000 trades, total: 95000
# Fetched 1000 trades, total: 96000
# Fetched 1000 trades, total: 97000
# Fetched 1000 trades, total: 98000
# Fetched 1000 trades, total: 99000
# Fetched 1000 trades, total: 100000
# Fetched 1000 trades, total: 101000
# Fetched 1000 trades, total: 102000
# Fetched 1000 trades, total: 103000
# Fetched 1000 trades, total: 104000
# Fetched 1000 trades, total: 105000
# Fetched 1000 trades, total: 106000
# Fetched 1000 trades, total: 107000
# Fetched 1000 trades, total: 108000
# Fetched 1000 trades, total: 109000
# Fetched 1000 trades, total: 110000
# Fetched 1000 trades, total: 111000
# Fetched 1000 trades, total: 112000
# Fetched 1000 trades, total: 113000
# Fetched 1000 trades, total: 114000
# Fetched 1000 trades, total: 115000
# Fetched 1000 trades, total: 116000
# Fetched 1000 trades, total: 117000
# Fetched 1000 trades, total: 118000
# Fetched 1000 trades, total: 119000
# Fetched 1000 trades, total: 120000
# Fetched 1000 trades, total: 121000
# Fetched 1000 trades, total: 122000
# Fetched 1000 trades, total: 123000
# Fetched 1000 trades, total: 124000
# Fetched 1000 trades, total: 125000
# Fetched 1000 trades, total: 126000
# Fetched 1000 trades, total: 127000
# Fetched 1000 trades, total: 128000
# Fetched 1000 trades, total: 129000
# Fetched 1000 trades, total: 130000
# Fetched 1000 trades, total: 131000
# Fetched 1000 trades, total: 132000
# Fetched 1000 trades, total: 133000
# Fetched 1000 trades, total: 134000
# Fetched 1000 trades, total: 135000
# Fetched 1000 trades, total: 136000
# Fetched 1000 trades, total: 137000
# Fetched 1000 trades, total: 138000
# Fetched 1000 trades, total: 139000
# Fetched 1000 trades, total: 140000
# Fetched 1000 trades, total: 141000
# Fetched 1000 trades, total: 142000
# Fetched 1000 trades, total: 143000
# Fetched 1000 trades, total: 144000
# Fetched 1000 trades, total: 145000
# Fetched 1000 trades, total: 146000
# Fetched 1000 trades, total: 147000
# Fetched 1000 trades, total: 148000
# Fetched 1000 trades, total: 149000
# Fetched 1000 trades, total: 150000
# Fetched 1000 trades, total: 151000
# Fetched 1000 trades, total: 152000
# Fetched 1000 trades, total: 153000
# Fetched 1000 trades, total: 154000
# Fetched 1000 trades, total: 155000
# Fetched 1000 trades, total: 156000
# Fetched 1000 trades, total: 157000
# Fetched 1000 trades, total: 158000
# Fetched 1000 trades, total: 159000
# Fetched 1000 trades, total: 160000
# Fetched 1000 trades, total: 161000
# Fetched 1000 trades, total: 162000
# Fetched 1000 trades, total: 163000
# Fetched 1000 trades, total: 164000
# Fetched 1000 trades, total: 165000
# Fetched 1000 trades, total: 166000
# Fetched 1000 trades, total: 167000
# Fetched 1000 trades, total: 168000
# Fetched 1000 trades, total: 169000
# Fetched 1000 trades, total: 170000
# Fetched 1000 trades, total: 171000
# Fetched 1000 trades, total: 172000
# Fetched 1000 trades, total: 173000
# Fetched 1000 trades, total: 174000
# Fetched 1000 trades, total: 175000
# Fetched 1000 trades, total: 176000
# Fetched 1000 trades, total: 177000
# Fetched 1000 trades, total: 178000
# Fetched 1000 trades, total: 179000
# Fetched 1000 trades, total: 180000
# Fetched 1000 trades, total: 181000
# Fetched 1000 trades, total: 182000
# Fetched 1000 trades, total: 183000
# Fetched 1000 trades, total: 184000
# Fetched 1000 trades, total: 185000
# Fetched 1000 trades, total: 186000
# Fetched 1000 trades, total: 187000
# Fetched 1000 trades, total: 188000
# Fetched 1000 trades, total: 189000
# Fetched 1000 trades, total: 190000
# Fetched 1000 trades, total: 191000
# Fetched 1000 trades, total: 192000
# Fetched 1000 trades, total: 193000
# Fetched 1000 trades, total: 194000
# Fetched 1000 trades, total: 195000
# Fetched 1000 trades, total: 196000
# Fetched 1000 trades, total: 197000
# Fetched 1000 trades, total: 198000
# Fetched 1000 trades, total: 199000
# Fetched 1000 trades, total: 200000
# Fetched 1000 trades, total: 201000
# Fetched 1000 trades, total: 202000
# Fetched 1000 trades, total: 203000
# Fetched 1000 trades, total: 204000
# Fetched 1000 trades, total: 205000
# Fetched 1000 trades, total: 206000
# Fetched 1000 trades, total: 207000
# Fetched 1000 trades, total: 208000
# Fetched 1000 trades, total: 209000
# Fetched 1000 trades, total: 210000
# Fetched 1000 trades, total: 211000
# Fetched 1000 trades, total: 212000
# Fetched 1000 trades, total: 213000
# Fetched 1000 trades, total: 214000
# Fetched 1000 trades, total: 215000
# Fetched 1000 trades, total: 216000
# Fetched 1000 trades, total: 217000
# Fetched 1000 trades, total: 218000
# Fetched 1000 trades, total: 219000
# Fetched 1000 trades, total: 220000
# Fetched 1000 trades, total: 221000
# Fetched 1000 trades, total: 222000
# Fetched 1000 trades, total: 223000
# Fetched 1000 trades, total: 224000
# Fetched 1000 trades, total: 225000
# Fetched 1000 trades, total: 226000
# Fetched 1000 trades, total: 227000
# Fetched 1000 trades, total: 228000
# Fetched 1000 trades, total: 229000
# Fetched 1000 trades, total: 230000
# Fetched 1000 trades, total: 231000
# Fetched 1000 trades, total: 232000
# Fetched 1000 trades, total: 233000
# Fetched 1000 trades, total: 234000
# Fetched 1000 trades, total: 235000
# Fetched 1000 trades, total: 236000
# Fetched 1000 trades, total: 237000
# Fetched 1000 trades, total: 238000
# Fetched 1000 trades, total: 239000
# Fetched 1000 trades, total: 240000
# Fetched 1000 trades, total: 241000
# Fetched 1000 trades, total: 242000
# Fetched 1000 trades, total: 243000
# Fetched 1000 trades, total: 244000
# Fetched 1000 trades, total: 245000
# Fetched 1000 trades, total: 246000
# Fetched 1000 trades, total: 247000
# Fetched 1000 trades, total: 248000
# Fetched 1000 trades, total: 249000
# Fetched 1000 trades, total: 250000
# Fetched 1000 trades, total: 251000
# Fetched 1000 trades, total: 252000
# Fetched 1000 trades, total: 253000
# Fetched 1000 trades, total: 254000
# Fetched 1000 trades, total: 255000
# Fetched 1000 trades, total: 256000
# Fetched 1000 trades, total: 257000
# Fetched 1000 trades, total: 258000
# Fetched 1000 trades, total: 259000
# Fetched 1000 trades, total: 260000
# Fetched 1000 trades, total: 261000
# Fetched 1000 trades, total: 262000
# Fetched 1000 trades, total: 263000
# Fetched 1000 trades, total: 264000
# Fetched 1000 trades, total: 265000
# Fetched 1000 trades, total: 266000
# Fetched 1000 trades, total: 267000
# Fetched 1000 trades, total: 268000
# Fetched 1000 trades, total: 269000
# Fetched 1000 trades, total: 270000
# Fetched 1000 trades, total: 271000
# Fetched 1000 trades, total: 272000
# Fetched 1000 trades, total: 273000
# Fetched 1000 trades, total: 274000
# Fetched 1000 trades, total: 275000
# Fetched 1000 trades, total: 276000
# Fetched 1000 trades, total: 277000
# Fetched 1000 trades, total: 278000
# Fetched 1000 trades, total: 279000
# Fetched 1000 trades, total: 280000
# Fetched 1000 trades, total: 281000
# Fetched 1000 trades, total: 282000
# Fetched 1000 trades, total: 283000
# Fetched 1000 trades, total: 284000
# Fetched 1000 trades, total: 285000
# Fetched 1000 trades, total: 286000
# Fetched 1000 trades, total: 287000
# Fetched 1000 trades, total: 288000
# Fetched 1000 trades, total: 289000
# Fetched 1000 trades, total: 290000
# Fetched 1000 trades, total: 291000
# Fetched 1000 trades, total: 292000
# Fetched 1000 trades, total: 293000
# Fetched 1000 trades, total: 294000
# Fetched 1000 trades, total: 295000
# Fetched 1000 trades, total: 296000
# Fetched 1000 trades, total: 297000
# Fetched 1000 trades, total: 298000
# Fetched 1000 trades, total: 299000
# Fetched 1000 trades, total: 300000
# Fetched 1000 trades, total: 301000
# Fetched 1000 trades, total: 302000
# Fetched 1000 trades, total: 303000
# Fetched 1000 trades, total: 304000
# Fetched 1000 trades, total: 305000
# Fetched 1000 trades, total: 306000
# Fetched 1000 trades, total: 307000
# Fetched 1000 trades, total: 308000
# Fetched 1000 trades, total: 309000
# Fetched 1000 trades, total: 310000
# Fetched 1000 trades, total: 311000
# Fetched 1000 trades, total: 312000
# Fetched 1000 trades, total: 313000
# Fetched 1000 trades, total: 314000
# Fetched 1000 trades, total: 315000
# Fetched 1000 trades, total: 316000
# Fetched 1000 trades, total: 317000
# Fetched 1000 trades, total: 318000
# Fetched 1000 trades, total: 319000
# Fetched 1000 trades, total: 320000
# Fetched 1000 trades, total: 321000
# Fetched 1000 trades, total: 322000
# Fetched 1000 trades, total: 323000
# Fetched 1000 trades, total: 324000
# Fetched 1000 trades, total: 325000
# Fetched 1000 trades, total: 326000
# Fetched 1000 trades, total: 327000
# Fetched 1000 trades, total: 328000
# Fetched 1000 trades, total: 329000
# Fetched 1000 trades, total: 330000
# Fetched 1000 trades, total: 331000
# Fetched 1000 trades, total: 332000
# Fetched 1000 trades, total: 333000
# Fetched 1000 trades, total: 334000
# Fetched 1000 trades, total: 335000
# Fetched 1000 trades, total: 336000
# Fetched 1000 trades, total: 337000
# Fetched 1000 trades, total: 338000
# Fetched 1000 trades, total: 339000
# Fetched 1000 trades, total: 340000
# Fetched 1000 trades, total: 341000
# Fetched 1000 trades, total: 342000
# Fetched 1000 trades, total: 343000
# Fetched 1000 trades, total: 344000
# Fetched 1000 trades, total: 345000
# Fetched 1000 trades, total: 346000
# Fetched 1000 trades, total: 347000
# Fetched 1000 trades, total: 348000
# Fetched 1000 trades, total: 349000
# Fetched 1000 trades, total: 350000
# Fetched 1000 trades, total: 351000
# Fetched 1000 trades, total: 352000
# Fetched 1000 trades, total: 353000
# Fetched 1000 trades, total: 354000
# Fetched 1000 trades, total: 355000
# Fetched 1000 trades, total: 356000
# Fetched 1000 trades, total: 357000
# Fetched 1000 trades, total: 358000
# Fetched 1000 trades, total: 359000
# Fetched 1000 trades, total: 360000
# Fetched 1000 trades, total: 361000
# Fetched 1000 trades, total: 362000
# Fetched 1000 trades, total: 363000
# Fetched 1000 trades, total: 364000
# Fetched 1000 trades, total: 365000
# Fetched 1000 trades, total: 366000
# Fetched 1000 trades, total: 367000
# Fetched 1000 trades, total: 368000
# Fetched 1000 trades, total: 369000
# Fetched 1000 trades, total: 370000
# Fetched 1000 trades, total: 371000
# Fetched 1000 trades, total: 372000
# Fetched 1000 trades, total: 373000
# Fetched 1000 trades, total: 374000
# Fetched 1000 trades, total: 375000
# Fetched 1000 trades, total: 376000
# Fetched 1000 trades, total: 377000
# Fetched 1000 trades, total: 378000
# Fetched 1000 trades, total: 379000
# Fetched 1000 trades, total: 380000
# Fetched 1000 trades, total: 381000
# Fetched 1000 trades, total: 382000
# Fetched 1000 trades, total: 383000
# Fetched 1000 trades, total: 384000
# Fetched 1000 trades, total: 385000
# Fetched 1000 trades, total: 386000
# Fetched 1000 trades, total: 387000
# Fetched 1000 trades, total: 388000
# Fetched 1000 trades, total: 389000
# Fetched 1000 trades, total: 390000
# Fetched 1000 trades, total: 391000
# Fetched 1000 trades, total: 392000
# Fetched 1000 trades, total: 393000
# Fetched 1000 trades, total: 394000
# Fetched 1000 trades, total: 395000
# Fetched 1000 trades, total: 396000
# Fetched 1000 trades, total: 397000
# Fetched 1000 trades, total: 398000
# Fetched 1000 trades, total: 399000
# Fetched 1000 trades, total: 400000
# Fetched 1000 trades, total: 401000
# Fetched 1000 trades, total: 402000
# Fetched 1000 trades, total: 403000
# Fetched 1000 trades, total: 404000
# Fetched 1000 trades, total: 405000
# Fetched 1000 trades, total: 406000
# Fetched 1000 trades, total: 407000
# Fetched 1000 trades, total: 408000
# Fetched 1000 trades, total: 409000
# Fetched 1000 trades, total: 410000
# Fetched 1000 trades, total: 411000
# Fetched 1000 trades, total: 412000
# Fetched 1000 trades, total: 413000
# Fetched 1000 trades, total: 414000
# Fetched 1000 trades, total: 415000
# Fetched 1000 trades, total: 416000
# Fetched 1000 trades, total: 417000
# Fetched 1000 trades, total: 418000
# Fetched 1000 trades, total: 419000
# Fetched 1000 trades, total: 420000
# Fetched 1000 trades, total: 421000
# Fetched 1000 trades, total: 422000
# Fetched 1000 trades, total: 423000
# Fetched 1000 trades, total: 424000
# Fetched 1000 trades, total: 425000
# Fetched 1000 trades, total: 426000
# Fetched 1000 trades, total: 427000
# Fetched 1000 trades, total: 428000
# Fetched 1000 trades, total: 429000
# Fetched 1000 trades, total: 430000
# Fetched 1000 trades, total: 431000
# Fetched 1000 trades, total: 432000
# Fetched 1000 trades, total: 433000
# Fetched 1000 trades, total: 434000
# Fetched 1000 trades, total: 435000
# Fetched 1000 trades, total: 436000
# Fetched 1000 trades, total: 437000
# Fetched 1000 trades, total: 438000
# Fetched 1000 trades, total: 439000
# Fetched 1000 trades, total: 440000
# Fetched 1000 trades, total: 441000
# Fetched 1000 trades, total: 442000
# Fetched 1000 trades, total: 443000
# Fetched 1000 trades, total: 444000
# Fetched 1000 trades, total: 445000
# Fetched 1000 trades, total: 446000
# Fetched 1000 trades, total: 447000
# Fetched 1000 trades, total: 448000
# Fetched 1000 trades, total: 449000
# Fetched 1000 trades, total: 450000
# Fetched 1000 trades, total: 451000
# Fetched 1000 trades, total: 452000
# Fetched 1000 trades, total: 453000
# Fetched 1000 trades, total: 454000
# Fetched 1000 trades, total: 455000
# Fetched 1000 trades, total: 456000
# Fetched 1000 trades, total: 457000
# Fetched 1000 trades, total: 458000
# Fetched 1000 trades, total: 459000
# Fetched 1000 trades, total: 460000
# Fetched 1000 trades, total: 461000
# Fetched 1000 trades, total: 462000
# Fetched 1000 trades, total: 463000
# Fetched 1000 trades, total: 464000
# Fetched 1000 trades, total: 465000
# Fetched 1000 trades, total: 466000
# Fetched 1000 trades, total: 467000
# Fetched 1000 trades, total: 468000
# Fetched 1000 trades, total: 469000
# Fetched 1000 trades, total: 470000
# Fetched 1000 trades, total: 471000
# Fetched 1000 trades, total: 472000
# Fetched 1000 trades, total: 473000
# Fetched 1000 trades, total: 474000
# Fetched 1000 trades, total: 475000
# Fetched 1000 trades, total: 476000
# Fetched 1000 trades, total: 477000
# Fetched 1000 trades, total: 478000
# Fetched 1000 trades, total: 479000
# Fetched 1000 trades, total: 480000
# Fetched 1000 trades, total: 481000
# Fetched 1000 trades, total: 482000
# Fetched 1000 trades, total: 483000
# Fetched 404 trades, total: 483404
# Total trades fetched: 483404
# Assigning trades to candles...
# Processing candles: 100%|██████████| 1440/1440 [00:06<00:00, 229.59it/s]
# Final DataFrame:
#                  time       open       high        low      close    volume  \
# 0 2025-08-30 00:41:00  108184.73  108226.27  108140.49  108187.81  33.83870
# 1 2025-08-30 00:42:00  108187.81  108187.81  108151.31  108151.31   7.02208
# 2 2025-08-30 00:43:00  108151.32  108206.53  108139.49  108196.50  29.22026
# 3 2025-08-30 00:44:00  108197.95  108210.89  108147.72  108147.73  11.78187
# 4 2025-08-30 00:45:00  108147.72  108192.00  108147.72  108187.99   7.51011
# 5 2025-08-30 00:46:00  108187.99  108188.00  108187.99  108187.99   1.56069
# 6 2025-08-30 00:47:00  108187.99  108266.23  108187.99  108266.23   5.12481
# 7 2025-08-30 00:48:00  108266.23  108266.23  108211.87  108211.88   6.70768
# 8 2025-08-30 00:49:00  108211.88  108264.93  108211.87  108264.93   6.52739
# 9 2025-08-30 00:50:00  108264.93  108288.79  108264.92  108288.79   3.69658
#
#    trades  buy_volume  sell_volume  buy_trades  sell_trades  delta_volume  \
# 0    4268    12.46165     21.37705         498          660      -8.91540
# 1    1561     1.10256      5.91952          84          317      -4.81696
# 2    1413    13.80650     15.41376         467          255      -1.60726
# 3    1853     2.18771      9.59416         259          398      -7.40645
# 4    1726     3.42040      4.08971         381          209      -0.66931
# 5     317     0.70081      0.85988         121          152      -0.15907
# 6    1214     4.61053      0.51428         436           67       4.09625
# 7    1256     0.47014      6.23754         100          265      -5.76740
# 8    1001     6.00245      0.52494         358           61       5.47751
# 9     648     1.68500      2.01158         241           54      -0.32658
#
#    avg_trade_size  imbalance           vwap  volatility
# 0        0.007928   0.368266  108176.664272       85.78
# 1        0.004498   0.157013  108163.411507       36.50
# 2        0.020680   0.472498  108162.523585       67.04
# 3        0.006358   0.185684  108166.620793       63.17
# 4        0.004351   0.455439  108179.474098       44.28
# 5        0.004923   0.449039  108187.994490        0.01
# 6        0.004221   0.899649  108227.074799       78.24
# 7        0.005341   0.070090  108249.827366       54.36
# 8        0.006521   0.919579  108224.092848       53.06
# 9        0.005705   0.455827  108281.237349       23.87
#
# Statistics:
# Total candles: 1440
# Total trades processed: 483404
# Total buy volume: 5714.34
# Total sell volume: 4866.96
# Volume difference: -42.00

# %%
df
# Out:
#                     time       open       high        low      close  \
# 0    2025-08-30 00:41:00  108184.73  108226.27  108140.49  108187.81
# 1    2025-08-30 00:42:00  108187.81  108187.81  108151.31  108151.31
# 2    2025-08-30 00:43:00  108151.32  108206.53  108139.49  108196.50
# 3    2025-08-30 00:44:00  108197.95  108210.89  108147.72  108147.73
# 4    2025-08-30 00:45:00  108147.72  108192.00  108147.72  108187.99
# ...                  ...        ...        ...        ...        ...
# 1435 2025-08-31 00:36:00  108956.19  108980.28  108956.18  108962.01
# 1436 2025-08-31 00:37:00  108962.01  108980.75  108962.01  108980.74
# 1437 2025-08-31 00:38:00  108980.75  109000.00  108980.74  109000.00
# 1438 2025-08-31 00:39:00  109000.00  109009.00  108999.99  109008.99
# 1439 2025-08-31 00:40:00  109008.99  109009.50  108991.25  109009.50
#
#         volume  trades  buy_volume  sell_volume  buy_trades  sell_trades  \
# 0     33.83870    4268    12.46165     21.37705         498          660
# 1      7.02208    1561     1.10256      5.91952          84          317
# 2     29.22026    1413    13.80650     15.41376         467          255
# 3     11.78187    1853     2.18771      9.59416         259          398
# 4      7.51011    1726     3.42040      4.08971         381          209
# ...        ...     ...         ...          ...         ...          ...
# 1435   2.91677    1786     1.31207      1.60470         268          252
# 1436   1.73775     708     1.49287      0.24488         158           43
# 1437   6.73559    1703     3.48467      3.25092         342          167
# 1438  14.01162     685     9.66764      4.34398         227           86
# 1439  13.91038     984     0.24099      0.02687          15           10
#
#       delta_volume  avg_trade_size  imbalance           vwap  volatility
# 0         -8.91540        0.007928   0.368266  108176.664272       85.78
# 1         -4.81696        0.004498   0.157013  108163.411507       36.50
# 2         -1.60726        0.020680   0.472498  108162.523585       67.04
# 3         -7.40645        0.006358   0.185684  108166.620793       63.17
# 4         -0.66931        0.004351   0.455439  108179.474098       44.28
# ...            ...             ...        ...            ...         ...
# 1435      -0.29263        0.001633   0.449837  108969.134073       24.10
# 1436       1.24799        0.002454   0.859082  108970.120307       18.74
# 1437       0.23375        0.003955   0.517352  108992.634101       19.26
# 1438       5.32366        0.020455   0.689973  109005.814729        9.01
# 1439       0.21412        0.014137   0.017324  109000.233713       18.25
#
# [1440 rows x 16 columns]
